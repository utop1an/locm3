# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
from extract import LOCM
from utils import read_plan
from evaluator import ExecutabilityEvaluator

# %%
# plan = "(unstack B C)\n(putdown B)\n(pickup A)\n(stack A B)\n(unstack C D)\nstack(C A)\n(pickup E)"
plan = """(switch_on ins9 sat1)
(turn_to sat1 dir3 dir7)
(calibrate sat1 ins9 dir3)
(turn_to sat1 dir1 dir3)
(take_image sat1 dir1 ins9 mod1)
(take_image sat1 dir1 ins9 mod2)
(take_image sat1 dir1 ins9 mod3)
(turn_to sat1 dir2 dir1)
(take_image sat1 dir2 ins9 mod1)
(take_image sat1 dir2 ins9 mod2)
(take_image sat1 dir2 ins9 mod3)
(turn_to sat1 dir3 dir2)
(take_image sat1 dir3 ins9 mod1)
(take_image sat1 dir3 ins9 mod2)
(take_image sat1 dir3 ins9 mod3)
(turn_to sat1 dir4 dir3)
(take_image sat1 dir4 ins9 mod1)
(take_image sat1 dir4 ins9 mod2)
(take_image sat1 dir4 ins9 mod3)
(turn_to sat1 dir5 dir4)
(take_image sat1 dir5 ins9 mod1)
(take_image sat1 dir5 ins9 mod2)
(take_image sat1 dir5 ins9 mod3)
(turn_to sat1 dir6 dir5)
(take_image sat1 dir6 ins9 mod1)
(take_image sat1 dir6 ins9 mod2)
(take_image sat1 dir6 ins9 mod3)
(turn_to sat1 dir7 dir6)
(take_image sat1 dir7 ins9 mod1)
(take_image sat1 dir7 ins9 mod2)
(take_image sat1 dir7 ins9 mod3)
(turn_to sat1 dir8 dir7)
(take_image sat1 dir8 ins9 mod1)
(take_image sat1 dir8 ins9 mod2)
(take_image sat1 dir8 ins9 mod3)
(turn_to sat1 dir9 dir8)
(take_image sat1 dir9 ins9 mod1)
(take_image sat1 dir9 ins9 mod2)
(take_image sat1 dir9 ins9 mod3)
(turn_to sat1 dir10 dir9)
(take_image sat1 dir10 ins9 mod1)
(take_image sat1 dir10 ins9 mod2)
(take_image sat1 dir10 ins9 mod3)
(switch_off ins9 sat1)
(switch_on ins14 sat1)
(turn_to sat1 dir3 dir10)
(calibrate sat1 ins14 dir3)
(turn_to sat1 dir1 dir3)
(take_image sat1 dir1 ins14 mod1)
(take_image sat1 dir1 ins14 mod3)
(turn_to sat1 dir2 dir1)
(take_image sat1 dir2 ins14 mod1)
(take_image sat1 dir2 ins14 mod3)
(turn_to sat1 dir3 dir2)
(take_image sat1 dir3 ins14 mod1)
(take_image sat1 dir3 ins14 mod3)
(turn_to sat1 dir4 dir3)
(take_image sat1 dir4 ins14 mod1)
(take_image sat1 dir4 ins14 mod3)
(turn_to sat1 dir5 dir4)
(take_image sat1 dir5 ins14 mod1)
(take_image sat1 dir5 ins14 mod3)
(turn_to sat1 dir6 dir5)
(take_image sat1 dir6 ins14 mod1)
(take_image sat1 dir6 ins14 mod3)
(turn_to sat1 dir7 dir6)
(take_image sat1 dir7 ins14 mod1)
(take_image sat1 dir7 ins14 mod3)
(turn_to sat1 dir8 dir7)
(take_image sat1 dir8 ins14 mod1)
(take_image sat1 dir8 ins14 mod3)
(turn_to sat1 dir9 dir8)
(take_image sat1 dir9 ins14 mod1)
(take_image sat1 dir9 ins14 mod3)
(turn_to sat1 dir10 dir9)
(take_image sat1 dir10 ins14 mod1)
(take_image sat1 dir10 ins14 mod3)
(switch_off ins14 sat1)
(turn_to sat1 dir2 dir10)
(switch_on ins5 sat2)
(turn_to sat2 dir9 dir2)
(calibrate sat2 ins5 dir9)
(turn_to sat2 dir1 dir9)
(take_image sat2 dir1 ins5 mod1)
(take_image sat2 dir1 ins5 mod2)
(take_image sat2 dir1 ins5 mod3)
(turn_to sat2 dir2 dir1)
(take_image sat2 dir2 ins5 mod1)
(take_image sat2 dir2 ins5 mod2)
(take_image sat2 dir2 ins5 mod3)
(turn_to sat2 dir3 dir2)
(take_image sat2 dir3 ins5 mod1)
(take_image sat2 dir3 ins5 mod2)
(take_image sat2 dir3 ins5 mod3)
(turn_to sat2 dir4 dir3)
(take_image sat2 dir4 ins5 mod1)
(take_image sat2 dir4 ins5 mod2)
(take_image sat2 dir4 ins5 mod3)
(turn_to sat2 dir5 dir4)
(take_image sat2 dir5 ins5 mod1)
(take_image sat2 dir5 ins5 mod2)
(take_image sat2 dir5 ins5 mod3)
(turn_to sat2 dir6 dir5)
(take_image sat2 dir6 ins5 mod1)
(take_image sat2 dir6 ins5 mod2)
(take_image sat2 dir6 ins5 mod3)
(turn_to sat2 dir7 dir6)
(take_image sat2 dir7 ins5 mod1)
(take_image sat2 dir7 ins5 mod2)
(take_image sat2 dir7 ins5 mod3)
(turn_to sat2 dir8 dir7)
(take_image sat2 dir8 ins5 mod1)
(take_image sat2 dir8 ins5 mod2)
(take_image sat2 dir8 ins5 mod3)
(turn_to sat2 dir9 dir8)
(take_image sat2 dir9 ins5 mod1)
(take_image sat2 dir9 ins5 mod2)
(take_image sat2 dir9 ins5 mod3)
(turn_to sat2 dir10 dir9)
(take_image sat2 dir10 ins5 mod1)
(take_image sat2 dir10 ins5 mod2)
(take_image sat2 dir10 ins5 mod3)
(switch_off ins5 sat2)
(switch_on ins16 sat2)
(turn_to sat2 dir6 dir10)
(calibrate sat2 ins16 dir6)
(turn_to sat2 dir1 dir6)
(take_image sat2 dir1 ins16 mod1)
(take_image sat2 dir1 ins16 mod2)
(take_image sat2 dir1 ins16 mod3)
(turn_to sat2 dir2 dir1)
(take_image sat2 dir2 ins16 mod1)
(take_image sat2 dir2 ins16 mod2)
(take_image sat2 dir2 ins16 mod3)
(turn_to sat2 dir3 dir2)
(take_image sat2 dir3 ins16 mod1)
(take_image sat2 dir3 ins16 mod2)
(take_image sat2 dir3 ins16 mod3)
(turn_to sat2 dir4 dir3)
(take_image sat2 dir4 ins16 mod1)
(take_image sat2 dir4 ins16 mod2)
(take_image sat2 dir4 ins16 mod3)
(turn_to sat2 dir5 dir4)
(take_image sat2 dir5 ins16 mod1)
(take_image sat2 dir5 ins16 mod2)
(take_image sat2 dir5 ins16 mod3)
(turn_to sat2 dir6 dir5)
(take_image sat2 dir6 ins16 mod1)
(take_image sat2 dir6 ins16 mod2)
(take_image sat2 dir6 ins16 mod3)
(turn_to sat2 dir7 dir6)
(take_image sat2 dir7 ins16 mod1)
(take_image sat2 dir7 ins16 mod2)
(take_image sat2 dir7 ins16 mod3)
(turn_to sat2 dir8 dir7)
(take_image sat2 dir8 ins16 mod1)
(take_image sat2 dir8 ins16 mod2)
(take_image sat2 dir8 ins16 mod3)
(turn_to sat2 dir9 dir8)
(take_image sat2 dir9 ins16 mod1)
(take_image sat2 dir9 ins16 mod2)
(take_image sat2 dir9 ins16 mod3)
(turn_to sat2 dir10 dir9)
(take_image sat2 dir10 ins16 mod1)
(take_image sat2 dir10 ins16 mod2)
(take_image sat2 dir10 ins16 mod3)
(switch_off ins16 sat2)
(switch_on ins6 sat3)
(turn_to sat3 dir5 dir2)
(calibrate sat3 ins6 dir5)
(turn_to sat3 dir1 dir5)
(take_image sat3 dir1 ins6 mod2)
(turn_to sat3 dir2 dir1)
(take_image sat3 dir2 ins6 mod2)
(turn_to sat3 dir3 dir2)
(take_image sat3 dir3 ins6 mod2)
(turn_to sat3 dir4 dir3)
(take_image sat3 dir4 ins6 mod2)
(turn_to sat3 dir5 dir4)
(take_image sat3 dir5 ins6 mod2)
(turn_to sat3 dir6 dir5)
(take_image sat3 dir6 ins6 mod2)
(turn_to sat3 dir7 dir6)
(take_image sat3 dir7 ins6 mod2)
(turn_to sat3 dir8 dir7)
(take_image sat3 dir8 ins6 mod2)
(turn_to sat3 dir9 dir8)
(take_image sat3 dir9 ins6 mod2)
(turn_to sat3 dir10 dir9)
(take_image sat3 dir10 ins6 mod2)
(switch_off ins6 sat3)
(switch_on ins13 sat3)
(turn_to sat3 dir2 dir10)
(calibrate sat3 ins13 dir2)
(turn_to sat3 dir1 dir2)
(take_image sat3 dir1 ins13 mod1)
(take_image sat3 dir1 ins13 mod2)
(turn_to sat3 dir2 dir1)
(take_image sat3 dir2 ins13 mod1)
(take_image sat3 dir2 ins13 mod2)
(turn_to sat3 dir3 dir2)
(take_image sat3 dir3 ins13 mod1)
(take_image sat3 dir3 ins13 mod2)
(turn_to sat3 dir4 dir3)
(take_image sat3 dir4 ins13 mod1)
(take_image sat3 dir4 ins13 mod2)
(turn_to sat3 dir5 dir4)
(take_image sat3 dir5 ins13 mod1)
(take_image sat3 dir5 ins13 mod2)
(turn_to sat3 dir6 dir5)
(take_image sat3 dir6 ins13 mod1)
(take_image sat3 dir6 ins13 mod2)
(turn_to sat3 dir7 dir6)
(take_image sat3 dir7 ins13 mod1)
(take_image sat3 dir7 ins13 mod2)
(turn_to sat3 dir8 dir7)
(take_image sat3 dir8 ins13 mod1)
(take_image sat3 dir8 ins13 mod2)
(turn_to sat3 dir9 dir8)
(take_image sat3 dir9 ins13 mod1)
(take_image sat3 dir9 ins13 mod2)
(turn_to sat3 dir10 dir9)
(take_image sat3 dir10 ins13 mod1)
(take_image sat3 dir10 ins13 mod2)
(switch_off ins13 sat3)
(switch_on ins17 sat3)
(turn_to sat3 dir4 dir10)
(calibrate sat3 ins17 dir4)
(turn_to sat3 dir1 dir4)
(take_image sat3 dir1 ins17 mod1)
(take_image sat3 dir1 ins17 mod2)
(take_image sat3 dir1 ins17 mod3)
(turn_to sat3 dir2 dir1)
(take_image sat3 dir2 ins17 mod1)
(take_image sat3 dir2 ins17 mod2)
(take_image sat3 dir2 ins17 mod3)
(turn_to sat3 dir3 dir2)
(take_image sat3 dir3 ins17 mod1)
(take_image sat3 dir3 ins17 mod2)
(take_image sat3 dir3 ins17 mod3)
(turn_to sat3 dir4 dir3)
(take_image sat3 dir4 ins17 mod1)
(take_image sat3 dir4 ins17 mod2)
(take_image sat3 dir4 ins17 mod3)
(turn_to sat3 dir5 dir4)
(take_image sat3 dir5 ins17 mod1)
(take_image sat3 dir5 ins17 mod2)
(take_image sat3 dir5 ins17 mod3)
(turn_to sat3 dir6 dir5)
(take_image sat3 dir6 ins17 mod1)
(take_image sat3 dir6 ins17 mod2)
(take_image sat3 dir6 ins17 mod3)
(turn_to sat3 dir7 dir6)
(take_image sat3 dir7 ins17 mod1)
(take_image sat3 dir7 ins17 mod2)
(take_image sat3 dir7 ins17 mod3)
(turn_to sat3 dir8 dir7)
(take_image sat3 dir8 ins17 mod1)
(take_image sat3 dir8 ins17 mod2)
(take_image sat3 dir8 ins17 mod3)
(turn_to sat3 dir9 dir8)
(take_image sat3 dir9 ins17 mod1)
(take_image sat3 dir9 ins17 mod2)
(take_image sat3 dir9 ins17 mod3)
(turn_to sat3 dir10 dir9)
(take_image sat3 dir10 ins17 mod1)
(take_image sat3 dir10 ins17 mod2)
(take_image sat3 dir10 ins17 mod3)
(switch_off ins17 sat3)
(turn_to sat3 dir7 dir10)
(switch_on ins2 sat4)
(turn_to sat4 dir10 dir1)
(calibrate sat4 ins2 dir10)
(turn_to sat4 dir1 dir10)
(take_image sat4 dir1 ins2 mod1)
(take_image sat4 dir1 ins2 mod2)
(take_image sat4 dir1 ins2 mod3)
(turn_to sat4 dir2 dir1)
(take_image sat4 dir2 ins2 mod1)
(take_image sat4 dir2 ins2 mod2)
(take_image sat4 dir2 ins2 mod3)
(turn_to sat4 dir3 dir2)
(take_image sat4 dir3 ins2 mod1)
(take_image sat4 dir3 ins2 mod2)
(take_image sat4 dir3 ins2 mod3)
(turn_to sat4 dir4 dir3)
(take_image sat4 dir4 ins2 mod1)
(take_image sat4 dir4 ins2 mod2)
(take_image sat4 dir4 ins2 mod3)
(turn_to sat4 dir5 dir4)
(take_image sat4 dir5 ins2 mod1)
(take_image sat4 dir5 ins2 mod2)
(take_image sat4 dir5 ins2 mod3)
(turn_to sat4 dir6 dir5)
(take_image sat4 dir6 ins2 mod1)
(take_image sat4 dir6 ins2 mod2)
(take_image sat4 dir6 ins2 mod3)
(turn_to sat4 dir7 dir6)
(take_image sat4 dir7 ins2 mod1)
(take_image sat4 dir7 ins2 mod2)
(take_image sat4 dir7 ins2 mod3)
(turn_to sat4 dir8 dir7)
(take_image sat4 dir8 ins2 mod1)
(take_image sat4 dir8 ins2 mod2)
(take_image sat4 dir8 ins2 mod3)
(turn_to sat4 dir9 dir8)
(take_image sat4 dir9 ins2 mod1)
(take_image sat4 dir9 ins2 mod2)
(take_image sat4 dir9 ins2 mod3)
(turn_to sat4 dir10 dir9)
(take_image sat4 dir10 ins2 mod1)
(take_image sat4 dir10 ins2 mod2)
(take_image sat4 dir10 ins2 mod3)
(switch_off ins2 sat4)
(switch_on ins3 sat5)
(calibrate sat5 ins3 dir2)
(turn_to sat5 dir1 dir2)
(take_image sat5 dir1 ins3 mod1)
(take_image sat5 dir1 ins3 mod2)
(turn_to sat5 dir2 dir1)
(take_image sat5 dir2 ins3 mod1)
(take_image sat5 dir2 ins3 mod2)
(turn_to sat5 dir3 dir2)
(take_image sat5 dir3 ins3 mod1)
(take_image sat5 dir3 ins3 mod2)
(turn_to sat5 dir4 dir3)
(take_image sat5 dir4 ins3 mod1)
(take_image sat5 dir4 ins3 mod2)
(turn_to sat5 dir5 dir4)
(take_image sat5 dir5 ins3 mod1)
(take_image sat5 dir5 ins3 mod2)
(turn_to sat5 dir6 dir5)
(take_image sat5 dir6 ins3 mod1)
(take_image sat5 dir6 ins3 mod2)
(turn_to sat5 dir7 dir6)
(take_image sat5 dir7 ins3 mod1)
(take_image sat5 dir7 ins3 mod2)
(turn_to sat5 dir8 dir7)
(take_image sat5 dir8 ins3 mod1)
(take_image sat5 dir8 ins3 mod2)
(turn_to sat5 dir9 dir8)
(take_image sat5 dir9 ins3 mod1)
(take_image sat5 dir9 ins3 mod2)
(turn_to sat5 dir10 dir9)
(take_image sat5 dir10 ins3 mod1)
(take_image sat5 dir10 ins3 mod2)
(switch_off ins3 sat5)
(switch_on ins10 sat6)
(turn_to sat6 dir10 dir6)"""
trace = read_plan(plan)

locm = LOCM(state_param=False)
model = locm.extract_model([trace])
pddl_domain = model.to_pddl_domain("test_bw")
# Out:
# Extracted sorts: {'dir2': 1, 'sat3': 2, 'mod1': 3, 'dir1': 4, 'dir3': 5, 'ins1': 6, 'sat2': 7, 'zero': 0}
# Extracted actions: defaultdict(<class 'set'>, {'switch_on': {switch_on.0, switch_on.1, switch_on.2}, 'calibrate': {calibrate.2, calibrate.1, calibrate.0, calibrate.3}, 'take_image': {take_image.0, take_image.3, take_image.1, take_image.4, take_image.2}, 'turn_to': {turn_to.1, turn_to.2, turn_to.3, turn_to.0}})
# [Type(object, None), <TypedObject dir2: s1>, <TypedObject sat3: s2>, <TypedObject mod1: s3>, <TypedObject dir1: s4>, <TypedObject dir3: s5>, <TypedObject ins1: s6>, <TypedObject sat2: s7>, <TypedObject zero: s0>]

# %%
evaluator = ExecutabilityEvaluator(pddl_domain, 'overall')
exe = evaluator.get_overall_executability('l', trace, set(), set())
print(exe)
# Out:
# 1.0

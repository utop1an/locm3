# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
from extract import LOCM2
from utils import read_plan, read_json_file
from evaluator import ExecutabilityEvaluator
from collections import defaultdict
import json

# %%
def test_cross_exe(domain_name, train_traces , prefix_traces, gt_traces=[]):
    debug = {}
    try:
        polocm2 = LOCM2(state_param=True, viz=False, debug=debug)
        model = polocm2.extract_model(train_traces)
        learned_domain = model.to_pddl_domain(domain_name)
        gt_filename = os.path.join('../../data', 'goose-benchmarks', 'tasks', domain_name, 'domain.pddl')
        
        evaluator = ExecutabilityEvaluator(learned_domain,gt_filename, debug=False)

        exe = evaluator.get_cross_executabilities(prefix_traces, gt_traces)
        return exe
    except Exception as e:
        print(f"Error processing domain {domain_name}: {e}")
        return 0,0
    
def test_balanced_exe(domain_name, train_traces, test_traces, test_invalid_traces):
    debug = {}
    try:
        polocm2 = LOCM2(state_param=True, viz=False, debug=debug)
        model = polocm2.extract_model(train_traces)
        learned_domain = model.to_pddl_domain(domain_name)
        gt_filename = os.path.join('../../data', 'goose-benchmarks', 'tasks', domain_name, 'domain.pddl')
        
        evaluator = ExecutabilityEvaluator(learned_domain, gt_filename, debug=False)
        exe = evaluator.get_balanced_executability(test_traces, test_invalid_traces)

        return exe
    except Exception as e:
        print(f"Error processing domain {domain_name}: {e}")
        return 0,0

# %%
plain_traces = defaultdict(list)
with open("../../data/plain_traces/plain_traces.txt", "r") as f:
    lines = f.readlines()
    for line in lines:
        details = line.split("&&")

        domain_name = details[0]
        plan = details[-1]

        plain_traces[domain_name].append(read_plan(plan))

# %%
train_traces = defaultdict(list)
data = read_json_file("../../data/training_data/traces_plan_r1.json")
for learning_obj in data:
    domain_name = learning_obj["domain"]
    train_traces[domain_name].append(learning_obj)

# %%
valid_traces = defaultdict(list)
invalid_traces = defaultdict(list)

with open("../../data/plain_traces/random_walks.txt", "r") as f:
    lines = f.readlines()
    for line in lines:
        details = line.split("&&")
        domain_name = details[0]
        is_valid = details[1] == "rand"
        plan = details[-1]
        if is_valid:
            valid_traces[domain_name].append(read_plan(plan))
        else:
            invalid_traces[domain_name].append(read_plan(plan))

# %%
with open("./cross_exe_results.csv", "w") as f:
    f.write("ID, Domain, len, objs, l_exe, gt_exe\n")
    for domain, items in train_traces.items():
        print(f"Testing domain: {domain}")
        for item in items:
            traces = item["traces"]

            try:
                coress_exe = test_cross_exe(domain, traces, plain_traces[domain], plain_traces[domain])
            except Exception as e:
                print(f"Error in balanced executability for domain {domain}: {e}")
                coress_exe = 0,0

        # Test balanced executability
            f.write(f"{item['id']}, {domain}, {item['total_length']}, {item['number_of_objects']}, {coress_exe[0]}, {coress_exe[1]}\n")
            f.flush()
            print(f"Cross Executability for {domain}: {coress_exe}")
# Out:
# Testing domain: blocksworld
# Cross Executability for blocksworld: (0.49481446543722457, 0.030303030303030304)
# Cross Executability for blocksworld: (0.54726748531232, 0.06060606060606061)
# Cross Executability for blocksworld: (0.5893494360618644, 0.9949494949494949)
# Cross Executability for blocksworld: (0.3736530849672458, 0.8580808080808081)
# Cross Executability for blocksworld: (0.5789783669363135, 0.6851050184383518)
# Cross Executability for blocksworld: (0.5789783669363135, 0.6809303350970018)
# Cross Executability for blocksworld: (0.5051855345627754, 0.9696969696969697)
# Cross Executability for blocksworld: (0.5893494360618644, 0.9941919191919192)
# Cross Executability for blocksworld: (0.5893494360618644, 0.9904040404040404)
# Cross Executability for blocksworld: (0.3736530849672458, 0.8442760942760943)
# Cross Executability for blocksworld: (0.5789783669363135, 0.6882435465768799)
# Cross Executability for blocksworld: (0.8188258265147725, 0.9026747824693893)
# Cross Executability for blocksworld: (1.0, 0.9839093664472452)
# Cross Executability for blocksworld: (1.0, 0.5950470979637645)
# Cross Executability for blocksworld: (0.5789783669363135, 0.6853054353054353)
# Cross Executability for blocksworld: (0.3736530849672458, 0.8409090909090909)
# Cross Executability for blocksworld: (1.0, 0.5953998316498317)
# Cross Executability for blocksworld: (1.0, 0.5949784783118117)
# Cross Executability for blocksworld: (1.0, 0.5952528317724396)
# Cross Executability for blocksworld: (1.0, 0.9245263420642209)
# Cross Executability for blocksworld: (0.3736530849672458, 0.8398989898989899)
# Cross Executability for blocksworld: (1.0, 0.5951195101195101)
# Cross Executability for blocksworld: (1.0, 0.5951981940618304)
# Cross Executability for blocksworld: (1.0, 0.5949589145422478)
# Cross Executability for blocksworld: (0.3736530849672458, 0.8486531986531988)
# Cross Executability for blocksworld: (1.0, 0.5949988227260954)
# Cross Executability for blocksworld: (1.0, 0.5947177948314312)
# Cross Executability for blocksworld: (1.0, 0.595088584255251)
# Cross Executability for blocksworld: (0.3736530849672458, 0.8341750841750842)
# Testing domain: childsnack
# Cross Executability for childsnack: (0.6024334084283064, 0.0)
# Cross Executability for childsnack: (0.8098048635038432, 0.8571428571428571)
# Cross Executability for childsnack: (0.7200781503077421, 1.0)
# Cross Executability for childsnack: (0.3633523034033238, 0.8163265306122449)
# Cross Executability for childsnack: (0.6610793307221878, 0.8360544217687075)
# Cross Executability for childsnack: (0.7827155176644973, 0.9290986394557823)
# Cross Executability for childsnack: (0.5709157905586477, 1.0)
# Cross Executability for childsnack: (0.7662551167653209, 0.01020408163265306)
# Cross Executability for childsnack: (0.7200781503077421, 1.0)
# Cross Executability for childsnack: (0.3633523034033238, 0.8163265306122449)
# Cross Executability for childsnack: (0.862882100892305, 0.9989795918367347)
# Cross Executability for childsnack: (0.862882100892305, 0.9993197278911565)
# Cross Executability for childsnack: (1.0, 1.0)
# Cross Executability for childsnack: (1.0, 1.0)
# Cross Executability for childsnack: (1.0, 1.0)
# Cross Executability for childsnack: (0.3633523034033238, 0.8163265306122449)
# Cross Executability for childsnack: (1.0, 1.0)
# Cross Executability for childsnack: (1.0, 1.0)
# Cross Executability for childsnack: (1.0, 1.0)
# Cross Executability for childsnack: (1.0, 1.0)
# Cross Executability for childsnack: (0.3633523034033238, 0.8163265306122449)
# Cross Executability for childsnack: (1.0, 1.0)
# Cross Executability for childsnack: (1.0, 1.0)
# Cross Executability for childsnack: (1.0, 1.0)
# Cross Executability for childsnack: (0.3633523034033238, 0.8163265306122449)
# Cross Executability for childsnack: (1.0, 1.0)
# Cross Executability for childsnack: (1.0, 1.0)
# Cross Executability for childsnack: (1.0, 1.0)
# Cross Executability for childsnack: (0.3633523034033238, 0.8163265306122449)
# Testing domain: ferry
# Cross Executability for ferry: (0.9578520899773342, 1.0)
# Cross Executability for ferry: (0.9792081487395772, 1.0)
# Cross Executability for ferry: (0.9578520899773342, 1.0)
# Cross Executability for ferry: (0.510801605107704, 0.0)
# Cross Executability for ferry: (0.978643941237757, 1.0)
# Cross Executability for ferry: (0.9578520899773342, 1.0)
# Cross Executability for ferry: (0.9792081487395772, 1.0)
# Cross Executability for ferry: (0.9792081487395772, 1.0)
# Cross Executability for ferry: (0.9578520899773342, 1.0)
# Cross Executability for ferry: (0.510801605107704, 0.0)
# Cross Executability for ferry: (0.978643941237757, 1.0)
# Cross Executability for ferry: (0.9792081487395772, 1.0)
# Cross Executability for ferry: (1.0, 1.0)
# Cross Executability for ferry: (0.9792081487395772, 1.0)
# Cross Executability for ferry: (1.0, 1.0)
# Cross Executability for ferry: (0.510801605107704, 0.0)
# Cross Executability for ferry: (1.0, 1.0)
# Cross Executability for ferry: (1.0, 1.0)
# Cross Executability for ferry: (0.9792081487395772, 1.0)
# Cross Executability for ferry: (1.0, 1.0)
# Cross Executability for ferry: (0.510801605107704, 0.0)
# Cross Executability for ferry: (1.0, 1.0)
# Cross Executability for ferry: (1.0, 1.0)
# Cross Executability for ferry: (1.0, 1.0)
# Cross Executability for ferry: (0.510801605107704, 0.0)
# Cross Executability for ferry: (1.0, 1.0)
# Cross Executability for ferry: (1.0, 1.0)
# Cross Executability for ferry: (1.0, 1.0)
# Cross Executability for ferry: (0.510801605107704, 0.0)
# Testing domain: floortile
# Cross Executability for floortile: (0.7498435621351305, 0.041408934707903786)
# Cross Executability for floortile: (0.779930280692354, 0.7000965472099493)
# Cross Executability for floortile: (0.2949216403227198, 0.8237800687285224)
# Cross Executability for floortile: (0.779930280692354, 0.6962291443143475)
# Cross Executability for floortile: (0.9182692688923887, 0.7638054600039136)
# Cross Executability for floortile: (0.7907720230119129, 0.796027803811309)
# Cross Executability for floortile: (0.90553737579592, 0.7601874411772486)
# Cross Executability for floortile: (0.9182692688923887, 0.7535697006315564)
# Cross Executability for floortile: (0.7880030291749968, 0.7131996211119923)
# Cross Executability for floortile: (0.7880030291749968, 0.6936839366098979)
# Cross Executability for floortile: (0.8264369542377002, 0.7140157511324348)
# Cross Executability for floortile: (0.9235730235381152, 0.8496661583736653)
# Cross Executability for floortile: (0.933296354852618, 0.7846949149185444)
# Cross Executability for floortile: (0.8206739067276809, 0.7580693229781464)
# Cross Executability for floortile: (0.8958233373816333, 0.7606544829740707)
# Cross Executability for floortile: (0.7880030291749968, 0.6966432606903398)
# Cross Executability for floortile: (0.9030393810388221, 0.8059031496763079)
# Cross Executability for floortile: (0.9108504233418626, 0.7787838446501758)
# Cross Executability for floortile: (0.933296354852618, 0.7822410624016799)
# Cross Executability for floortile: (0.8208104855217053, 0.7412926663164081)
# Cross Executability for floortile: (0.7880030291749968, 0.6897555646933531)
# Cross Executability for floortile: (0.9108504233418626, 0.7793856816913592)
# Cross Executability for floortile: (0.9108504233418626, 0.7772890694870136)
# Cross Executability for floortile: (0.9079836555625677, 0.9192488322054166)
# Cross Executability for floortile: (0.7880030291749968, 0.7079278861160293)
# Cross Executability for floortile: (0.9643730163965127, 0.8970736501158616)
# Cross Executability for floortile: (0.9189231718245053, 0.8554611796674672)
# Cross Executability for floortile: (0.9503589901641174, 0.8392654555891462)
# Cross Executability for floortile: (0.7880030291749968, 0.6978659281598939)
# Testing domain: miconic
# Cross Executability for miconic: (0.5810149667677484, 0.9335954785954785)
# Cross Executability for miconic: (0.9111635172706177, 1.0)
# Cross Executability for miconic: (0.5542501293194114, 0.9155916305916306)
# Cross Executability for miconic: (0.6767979274387029, 0.7810004810004809)
# Cross Executability for miconic: (0.9150928598387126, 1.0)
# Cross Executability for miconic: (0.8510302922018324, 1.0)
# Cross Executability for miconic: (0.8989926190396083, 1.0)
# Cross Executability for miconic: (0.9973255130676419, 1.0)
# Cross Executability for miconic: (0.8510302922018324, 1.0)
# Cross Executability for miconic: (0.6767979274387029, 0.7833742183742184)
# Cross Executability for miconic: (0.9150928598387126, 1.0)
# Cross Executability for miconic: (0.8510302922018324, 1.0)
# Cross Executability for miconic: (0.9973255130676419, 1.0)
# Cross Executability for miconic: (0.9973255130676419, 1.0)
# Cross Executability for miconic: (0.9964962018935033, 1.0)
# Cross Executability for miconic: (0.6767979274387029, 0.783006253006253)
# Cross Executability for miconic: (0.9150928598387126, 1.0)
# Cross Executability for miconic: (0.9973255130676419, 1.0)
# Cross Executability for miconic: (0.9992229992229992, 1.0)
# Cross Executability for miconic: (0.9964962018935033, 1.0)
# Cross Executability for miconic: (0.6767979274387029, 0.7853150553150553)
# Cross Executability for miconic: (0.9973255130676419, 1.0)
# Cross Executability for miconic: (0.9992229992229992, 1.0)
# Cross Executability for miconic: (0.9964962018935033, 1.0)
# Cross Executability for miconic: (0.6767979274387029, 0.7832515632515633)
# Cross Executability for miconic: (0.9973255130676419, 1.0)
# Cross Executability for miconic: (0.9992229992229992, 1.0)
# Cross Executability for miconic: (0.9964962018935033, 1.0)
# Cross Executability for miconic: (0.6767979274387029, 0.7846657046657047)
# Testing domain: rovers
# Cross Executability for rovers: (0.2313214018212552, 0.12070707070707071)
# Cross Executability for rovers: (0.2833351898920558, 0.6868686868686869)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Cross Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Cross Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Cross Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Cross Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Cross Executability for rovers: (0, 0)
# Cross Executability for rovers: (0.3196584665035172, 0.12121212121212122)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Cross Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Cross Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Cross Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Cross Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Cross Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Cross Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Cross Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Cross Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Cross Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Cross Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Cross Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Cross Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Cross Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Cross Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Cross Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Cross Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Cross Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Cross Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Cross Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Cross Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Cross Executability for rovers: (0, 0)
# Testing domain: satellite
# Cross Executability for satellite: (0.5125100501651072, 0.0)
# Cross Executability for satellite: (0.5425411908583002, 1.0)
# Cross Executability for satellite: (0.5575567612048966, 0.38953502058598055)
# Cross Executability for satellite: (0.4719595148243713, 0.09090909090909091)
# Cross Executability for satellite: (0.5026636299863384, 0.9292929292929293)
# Cross Executability for satellite: (0.7674391202066692, 0.7272727272727273)
# Cross Executability for satellite: (0.8173606661540413, 0.8988593330703887)
# Cross Executability for satellite: (0.030031140693192977, 0.7575757575757576)
# Cross Executability for satellite: (0.6811068549626126, 0.8686868686868687)
# Cross Executability for satellite: (0.4719595148243713, 0.09090909090909091)
# Cross Executability for satellite: (0.7397759543641615, 0.12729233659945757)
# Cross Executability for satellite: (0.7033159459072449, 0.8471221371221371)
# Cross Executability for satellite: (0.9616512676315028, 0.494949494949495)
# Cross Executability for satellite: (0.9616512676315028, 0.494949494949495)
# Cross Executability for satellite: (1.0, 0.6262150032193747)
# Cross Executability for satellite: (0.4719595148243713, 0.09090909090909091)
# Cross Executability for satellite: (0.8165596149107356, 0.7290116980092929)
# Cross Executability for satellite: (0.9838494989047065, 0.0)
# Cross Executability for satellite: (0.9616512676315028, 0.494949494949495)
# Cross Executability for satellite: (0.9661697746124942, 0.0)
# Cross Executability for satellite: (0.4719595148243713, 0.09090909090909091)
# Cross Executability for satellite: (1.0, 0.6261165961687069)
# Cross Executability for satellite: (0.9838494989047065, 0.0)
# Cross Executability for satellite: (0.9838494989047065, 0.0)
# Cross Executability for satellite: (0.4719595148243713, 0.09090909090909091)
# Cross Executability for satellite: (0.9838494989047065, 0.0)
# Cross Executability for satellite: (1.0, 0.6254091000146901)
# Cross Executability for satellite: (0.9838494989047065, 0.0)
# Cross Executability for satellite: (0.4719595148243713, 0.09090909090909091)
# Testing domain: sokoban
# Cross Executability for sokoban: (0.6052985729520934, 0.9986700336700336)
# Cross Executability for sokoban: (0.9404997834451722, 0.825753267288346)
# Cross Executability for sokoban: (0.9404997834451722, 0.8277716456767487)
# Cross Executability for sokoban: (0.4845390720827535, 0.16035353535353536)
# Cross Executability for sokoban: (0.9782930093146418, 0.7599063379665313)
# Cross Executability for sokoban: (0.20170075626832829, 0.0)
# Cross Executability for sokoban: (0.6591396135911195, 1.0)

# %%
with open("./balanced_exe_results.csv", "w") as f:
    f.write("ID, Domain, len, objs, valid_exe, invalid_exe\n")
    for domain, items in train_traces.items():
        print(f"Testing domain: {domain}")
        for item in items:
            traces = item["traces"]

            try:
                balanced_exe = test_balanced_exe(domain, traces, valid_traces[domain], invalid_traces[domain])
            except Exception as e:
                print(f"Error in balanced executability for domain {domain}: {e}")
                balanced_exe = 0,0

        # Test balanced executability
            f.write(f"{item['id']}, {domain}, {item['total_length']}, {item['number_of_objects']}, {balanced_exe[0]}, {balanced_exe[1]}\n")
            f.flush()
            print(f"Balanced Executability for {domain}: {balanced_exe}")
# Out:
# Testing domain: blocksworld
# Balanced Executability for blocksworld: (0.15850073419758487, 0.17101068727307364)
# Balanced Executability for blocksworld: (0.2333423618833991, 0.24442387790960024)
# Balanced Executability for blocksworld: (0.28044776143401734, 0.2989688392798139)
# Balanced Executability for blocksworld: (0.1953716950739421, 0.21169369584782874)
# Balanced Executability for blocksworld: (0.2445116775437157, 0.2645264406240145)
# Balanced Executability for blocksworld: (0.2445116775437157, 0.2645264406240145)
# Balanced Executability for blocksworld: (0.19686526926633768, 0.20924938222516934)
# Balanced Executability for blocksworld: (0.28044776143401734, 0.2989688392798139)
# Balanced Executability for blocksworld: (0.28044776143401734, 0.2989688392798139)
# Balanced Executability for blocksworld: (0.1953716950739421, 0.21169369584782874)
# Balanced Executability for blocksworld: (0.28554283604900293, 0.3046678743600073)
# Balanced Executability for blocksworld: (0.41375391405604867, 0.43733275177065734)
# Balanced Executability for blocksworld: (0.39955124583067786, 0.42343777166612806)
# Balanced Executability for blocksworld: (0.4294065375510209, 0.45070838215259035)
# Balanced Executability for blocksworld: (0.2445116775437157, 0.2645264406240145)
# Balanced Executability for blocksworld: (0.1953716950739421, 0.21169369584782874)
# Balanced Executability for blocksworld: (0.4453188787126932, 0.46751303776527464)
# Balanced Executability for blocksworld: (0.4113752384424625, 0.4338859472260196)
# Balanced Executability for blocksworld: (0.4671028675115175, 0.487929117463483)
# Balanced Executability for blocksworld: (0.44158093133877063, 0.46835650661812317)
# Balanced Executability for blocksworld: (0.1953716950739421, 0.21169369584782874)
# Balanced Executability for blocksworld: (0.4453188787126932, 0.46751303776527464)
# Balanced Executability for blocksworld: (0.4671028675115175, 0.487929117463483)
# Balanced Executability for blocksworld: (0.4453188787126932, 0.46751303776527464)
# Balanced Executability for blocksworld: (0.1953716950739421, 0.21169369584782874)
# Balanced Executability for blocksworld: (0.4453188787126932, 0.46751303776527464)
# Balanced Executability for blocksworld: (0.4671028675115175, 0.487929117463483)
# Balanced Executability for blocksworld: (0.4453188787126932, 0.46751303776527464)
# Balanced Executability for blocksworld: (0.1953716950739421, 0.21169369584782874)
# Testing domain: childsnack
# Balanced Executability for childsnack: (0.4347991332175006, 0.439169194373276)
# Balanced Executability for childsnack: (0.5207996878405041, 0.5303189082270715)
# Balanced Executability for childsnack: (0.5808313946069048, 0.5948903392525842)
# Balanced Executability for childsnack: (0.2569170323251956, 0.2667233007921783)
# Balanced Executability for childsnack: (0.293791817592838, 0.29989113069470213)
# Balanced Executability for childsnack: (0.44369194864092826, 0.4510367278224421)
# Balanced Executability for childsnack: (0.4803173192076253, 0.48807380780595067)
# Balanced Executability for childsnack: (0.49540925533272473, 0.5019589480813971)
# Balanced Executability for childsnack: (0.5808313946069048, 0.5948903392525842)
# Balanced Executability for childsnack: (0.2569170323251956, 0.2667233007921783)
# Balanced Executability for childsnack: (0.7140536867705235, 0.7266192108156394)
# Balanced Executability for childsnack: (0.7140536867705235, 0.7266192108156394)
# Balanced Executability for childsnack: (0.7253727753727753, 0.7365748409753512)
# Balanced Executability for childsnack: (0.7253727753727753, 0.7365748409753512)
# Balanced Executability for childsnack: (0.7253727753727753, 0.7365748409753512)
# Balanced Executability for childsnack: (0.2569170323251956, 0.2667233007921783)
# Balanced Executability for childsnack: (0.6607959024158003, 0.6710525259887505)
# Balanced Executability for childsnack: (0.7253727753727753, 0.7365748409753512)
# Balanced Executability for childsnack: (0.7253727753727753, 0.7365748409753512)
# Balanced Executability for childsnack: (0.7253727753727753, 0.7365748409753512)
# Balanced Executability for childsnack: (0.2569170323251956, 0.2667233007921783)
# Balanced Executability for childsnack: (0.7253727753727753, 0.7365748409753512)
# Balanced Executability for childsnack: (0.7253727753727753, 0.7365748409753512)
# Balanced Executability for childsnack: (0.7253727753727753, 0.7365748409753512)
# Balanced Executability for childsnack: (0.2569170323251956, 0.2667233007921783)
# Balanced Executability for childsnack: (0.7253727753727753, 0.7365748409753512)
# Balanced Executability for childsnack: (0.7253727753727753, 0.7365748409753512)
# Balanced Executability for childsnack: (0.7253727753727753, 0.7365748409753512)
# Balanced Executability for childsnack: (0.2569170323251956, 0.2667233007921783)
# Testing domain: ferry
# Balanced Executability for ferry: (0.2527733889395089, 0.27359457786617475)
# Balanced Executability for ferry: (0.260590355143869, 0.28120518282709245)
# Balanced Executability for ferry: (0.2527733889395089, 0.27359457786617475)
# Balanced Executability for ferry: (0.18721792880167892, 0.2021374985804217)
# Balanced Executability for ferry: (0.9166416321303616, 0.9239317119620987)
# Balanced Executability for ferry: (0.2527733889395089, 0.27359457786617475)
# Balanced Executability for ferry: (0.260590355143869, 0.28120518282709245)
# Balanced Executability for ferry: (0.260590355143869, 0.28120518282709245)
# Balanced Executability for ferry: (0.2527733889395089, 0.27359457786617475)
# Balanced Executability for ferry: (0.18721792880167892, 0.2021374985804217)
# Balanced Executability for ferry: (0.9166416321303616, 0.9239317119620987)
# Balanced Executability for ferry: (0.260590355143869, 0.28120518282709245)
# Balanced Executability for ferry: (0.9852426183020898, 0.9929631502820168)
# Balanced Executability for ferry: (0.260590355143869, 0.28120518282709245)
# Balanced Executability for ferry: (0.9852426183020898, 0.9929631502820168)
# Balanced Executability for ferry: (0.18721792880167892, 0.2021374985804217)
# Balanced Executability for ferry: (0.9852426183020898, 0.9929631502820168)
# Balanced Executability for ferry: (0.9852426183020898, 0.9929631502820168)
# Balanced Executability for ferry: (0.260590355143869, 0.28120518282709245)
# Balanced Executability for ferry: (0.9852426183020898, 0.9929631502820168)
# Balanced Executability for ferry: (0.18721792880167892, 0.2021374985804217)
# Balanced Executability for ferry: (0.9852426183020898, 0.9929631502820168)
# Balanced Executability for ferry: (0.9852426183020898, 0.9929631502820168)
# Balanced Executability for ferry: (0.9852426183020898, 0.9929631502820168)
# Balanced Executability for ferry: (0.18721792880167892, 0.2021374985804217)
# Balanced Executability for ferry: (0.9852426183020898, 0.9929631502820168)
# Balanced Executability for ferry: (0.9852426183020898, 0.9929631502820168)
# Balanced Executability for ferry: (0.9852426183020898, 0.9929631502820168)
# Balanced Executability for ferry: (0.18721792880167892, 0.2021374985804217)
# Testing domain: floortile
# Balanced Executability for floortile: (0.10321982891333326, 0.10593872826508527)
# Balanced Executability for floortile: (0.13338380920190018, 0.1387744659794028)
# Balanced Executability for floortile: (0.14326456405399723, 0.15122930484708563)
# Balanced Executability for floortile: (0.136646907871654, 0.14218087855921258)
# Balanced Executability for floortile: (0.1548865014684614, 0.16245119291158713)
# Balanced Executability for floortile: (0.1385777592998317, 0.14480971831411357)
# Balanced Executability for floortile: (0.1257323440099658, 0.13052810585738148)
# Balanced Executability for floortile: (0.1548865014684614, 0.16245119291158713)
# Balanced Executability for floortile: (0.1470700132082694, 0.15349815912893128)
# Balanced Executability for floortile: (0.1503331118780232, 0.15690457170874106)
# Balanced Executability for floortile: (0.1576862863208838, 0.16334953957686452)
# Balanced Executability for floortile: (0.14699160022321148, 0.15335419305322057)
# Balanced Executability for floortile: (0.14882137357932204, 0.15512006022415706)
# Balanced Executability for floortile: (0.1592200182488379, 0.16036929042206385)
# Balanced Executability for floortile: (0.15040598999378826, 0.15741267345277005)
# Balanced Executability for floortile: (0.1503331118780232, 0.15690457170874106)
# Balanced Executability for floortile: (0.1778752110496517, 0.18219866682456382)
# Balanced Executability for floortile: (0.1453247983570933, 0.15111818974038463)
# Balanced Executability for floortile: (0.1498053098317664, 0.1561567091992017)
# Balanced Executability for floortile: (0.150809111100368, 0.1563276422020568)
# Balanced Executability for floortile: (0.1503331118780232, 0.15690457170874106)
# Balanced Executability for floortile: (0.1453247983570933, 0.15111818974038463)
# Balanced Executability for floortile: (0.1453247983570933, 0.15111818974038463)
# Balanced Executability for floortile: (0.15158865784531544, 0.1553484782400021)
# Balanced Executability for floortile: (0.1503331118780232, 0.15690457170874106)
# Balanced Executability for floortile: (0.20745897627920276, 0.20960830286744694)
# Balanced Executability for floortile: (0.15901100236346255, 0.16584188288991308)
# Balanced Executability for floortile: (0.2092833897320285, 0.21269583101105302)
# Balanced Executability for floortile: (0.1503331118780232, 0.15690457170874106)
# Testing domain: miconic
# Balanced Executability for miconic: (0.4067749856576035, 0.42148743229294655)
# Balanced Executability for miconic: (0.5755434762081152, 0.5809179411743939)
# Balanced Executability for miconic: (0.40447545950527736, 0.4047943533448093)
# Balanced Executability for miconic: (0.29173154324976125, 0.30018257151769484)
# Balanced Executability for miconic: (0.6489258953690287, 0.656339444237456)
# Balanced Executability for miconic: (0.19915024108398222, 0.20406025480468595)
# Balanced Executability for miconic: (0.5769368506356042, 0.5804657334036892)
# Balanced Executability for miconic: (0.7250609816128881, 0.7357758363788501)
# Balanced Executability for miconic: (0.19884755643653812, 0.20379736961707395)
# Balanced Executability for miconic: (0.29173154324976125, 0.30018257151769484)
# Balanced Executability for miconic: (0.6489258953690287, 0.656339444237456)
# Balanced Executability for miconic: (0.19915024108398222, 0.20406025480468595)
# Balanced Executability for miconic: (0.7250609816128881, 0.7357758363788501)
# Balanced Executability for miconic: (0.7250609816128881, 0.7357758363788501)
# Balanced Executability for miconic: (0.6519707274961363, 0.6593855807416121)
# Balanced Executability for miconic: (0.29173154324976125, 0.30018257151769484)
# Balanced Executability for miconic: (0.6489258953690287, 0.656339444237456)
# Balanced Executability for miconic: (0.7250609816128881, 0.7357758363788501)
# Balanced Executability for miconic: (0.8386507464692472, 0.8543027472626729)
# Balanced Executability for miconic: (0.6519707274961363, 0.6593855807416121)
# Balanced Executability for miconic: (0.29173154324976125, 0.30018257151769484)
# Balanced Executability for miconic: (0.7250609816128881, 0.7357758363788501)
# Balanced Executability for miconic: (0.8386507464692472, 0.8543027472626729)
# Balanced Executability for miconic: (0.6519707274961363, 0.6593855807416121)
# Balanced Executability for miconic: (0.29173154324976125, 0.30018257151769484)
# Balanced Executability for miconic: (0.7250609816128881, 0.7357758363788501)
# Balanced Executability for miconic: (0.8386507464692472, 0.8543027472626729)
# Balanced Executability for miconic: (0.6519707274961363, 0.6593855807416121)
# Balanced Executability for miconic: (0.29173154324976125, 0.30018257151769484)
# Testing domain: rovers
# Balanced Executability for rovers: (0.1666599267323572, 0.17050234341365297)
# Balanced Executability for rovers: (0.3023745264210245, 0.30866806261541074)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Balanced Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Balanced Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Balanced Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Balanced Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Balanced Executability for rovers: (0, 0)
# Balanced Executability for rovers: (0.24468433907875412, 0.2522664111525516)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Balanced Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Balanced Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Balanced Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Balanced Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Balanced Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Balanced Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Balanced Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Balanced Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Balanced Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Balanced Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Balanced Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Balanced Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Balanced Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Balanced Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Balanced Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Balanced Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Balanced Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Balanced Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Balanced Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Balanced Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Balanced Executability for rovers: (0, 0)
# Testing domain: satellite
# Balanced Executability for satellite: (0.06981546876982055, 0.07293669803507932)
# Balanced Executability for satellite: (0.09532484777841403, 0.09909658942288152)
# Balanced Executability for satellite: (0.10923211285003857, 0.113272413096398)
# Balanced Executability for satellite: (0.06972693819998663, 0.07263215966287266)
# Balanced Executability for satellite: (0.08186224881409145, 0.0847502981431317)
# Balanced Executability for satellite: (0.08712651864341547, 0.09067887715392682)
# Balanced Executability for satellite: (0.5371813402670391, 0.5401792474432805)
# Balanced Executability for satellite: (0.054387614325854206, 0.053546067865787146)
# Balanced Executability for satellite: (0.12920686746068924, 0.1306241709216987)
# Balanced Executability for satellite: (0.06972693819998663, 0.07263215966287266)
# Balanced Executability for satellite: (0.0840973215555902, 0.08698739362011895)
# Balanced Executability for satellite: (0.07268590235001687, 0.07535193845325577)
# Balanced Executability for satellite: (0.355911302799082, 0.3575624089463791)
# Balanced Executability for satellite: (0.355911302799082, 0.3575624089463791)
# Balanced Executability for satellite: (0.9321277967389989, 0.9396810027540142)
# Balanced Executability for satellite: (0.06972693819998663, 0.07263215966287266)
# Balanced Executability for satellite: (0.09300327493725095, 0.09707436858203437)
# Balanced Executability for satellite: (0.4803573507616205, 0.48467574925492984)
# Balanced Executability for satellite: (0.3583663936708036, 0.3598252306715885)
# Balanced Executability for satellite: (0.4699360231538847, 0.4743441765548402)
# Balanced Executability for satellite: (0.06972693819998663, 0.07263215966287266)
# Balanced Executability for satellite: (0.9321277967389989, 0.9396810027540142)
# Balanced Executability for satellite: (0.4803573507616205, 0.48467574925492984)
# Balanced Executability for satellite: (0.4803573507616205, 0.48467574925492984)
# Balanced Executability for satellite: (0.06972693819998663, 0.07263215966287266)
# Balanced Executability for satellite: (0.4803573507616205, 0.48467574925492984)
# Balanced Executability for satellite: (0.9321277967389989, 0.9396810027540142)
# Balanced Executability for satellite: (0.4803573507616205, 0.48467574925492984)
# Balanced Executability for satellite: (0.06972693819998663, 0.07263215966287266)
# Testing domain: sokoban
# Balanced Executability for sokoban: (0.3830017847438288, 0.42715350189186)
# Balanced Executability for sokoban: (0.5455733001743981, 0.6021313589524981)
# Balanced Executability for sokoban: (0.5455733001743981, 0.6021313589524981)
# Balanced Executability for sokoban: (0.12780875755481116, 0.1636376816184043)
# Balanced Executability for sokoban: (0.7881802437605544, 0.843103350817143)
# Balanced Executability for sokoban: (0.2095432357568039, 0.22676127623964878)
# Balanced Executability for sokoban: (0.963583745114337, 1.0136234760339324)
# Balanced Executability for sokoban: (0.7881802437605544, 0.8417399502380563)
# Balanced Executability for sokoban: (0.7881802437605544, 0.8417399502380563)
# Balanced Executability for sokoban: (0.12780875755481116, 0.1636376816184043)
# Balanced Executability for sokoban: (0.9998462765985859, 1.0572484329940097)
# Balanced Executability for sokoban: (0.2095432357568039, 0.22676127623964878)
# Balanced Executability for sokoban: (0.963583745114337, 1.0136234760339324)
# Balanced Executability for sokoban: (1.0, 1.0564981887046059)
# Balanced Executability for sokoban: (1.0, 1.0564981887046059)
# Balanced Executability for sokoban: (0.12780875755481116, 0.1636376816184043)
# Balanced Executability for sokoban: (0.9998462765985859, 1.0572484329940097)
# Balanced Executability for sokoban: (0.963583745114337, 1.0136234760339324)
# Balanced Executability for sokoban: (1.0, 1.0564981887046059)
# Balanced Executability for sokoban: (1.0, 1.0564981887046059)
# Balanced Executability for sokoban: (0.12780875755481116, 0.1636376816184043)
# Balanced Executability for sokoban: (0.963583745114337, 1.0136234760339324)
# Balanced Executability for sokoban: (1.0, 1.0564981887046059)
# Balanced Executability for sokoban: (1.0, 1.0564981887046059)
# Balanced Executability for sokoban: (0.12780875755481116, 0.1636376816184043)
# Balanced Executability for sokoban: (0.963583745114337, 1.0136234760339324)
# Balanced Executability for sokoban: (1.0, 1.0564981887046059)
# Balanced Executability for sokoban: (1.0, 1.0564981887046059)
# Balanced Executability for sokoban: (0.12780875755481116, 0.1636376816184043)
# Testing domain: spanner
# Balanced Executability for spanner: (0.7204377791555583, 0.7204377791555585)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (0.8903378717192332, 0.8903378717192333)
# Balanced Executability for spanner: (0.9095774362231731, 0.9095774362231731)
# Balanced Executability for spanner: (0.8903378717192332, 0.8903378717192333)
# Balanced Executability for spanner: (0.8903378717192332, 0.8903378717192333)
# Balanced Executability for spanner: (0.9095774362231731, 0.9095774362231731)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (0.9095774362231731, 0.9095774362231731)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (0.8903378717192332, 0.8903378717192333)
# Balanced Executability for spanner: (0.9095774362231731, 0.9095774362231731)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (0.9095774362231731, 0.9095774362231731)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (0.9095774362231731, 0.9095774362231731)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (0.9095774362231731, 0.9095774362231731)
# Balanced Executability for spanner: (0.9095774362231731, 0.9095774362231731)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (0.9095774362231731, 0.9095774362231731)
# Balanced Executability for spanner: (0.9095774362231731, 0.9095774362231731)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (0.9095774362231731, 0.9095774362231731)
# Testing domain: transport
# Balanced Executability for transport: (0.8021610588161701, 0.8108194339372773)
# Balanced Executability for transport: (0.33900164528645016, 0.3509111452306919)
# Balanced Executability for transport: (0.8021610588161701, 0.8108194339372773)
# Balanced Executability for transport: (0.16203659056399042, 0.18210100625681877)
# Balanced Executability for transport: (0.7929520743549477, 0.8020534236519155)
# Balanced Executability for transport: (0.7929520743549477, 0.8020534236519155)
# Balanced Executability for transport: (0.8021610588161701, 0.8108194339372773)
# Balanced Executability for transport: (0.8021610588161701, 0.8108194339372773)
# Balanced Executability for transport: (0.8021610588161701, 0.8108194339372773)
# Balanced Executability for transport: (0.16203659056399042, 0.18210100625681877)
# Balanced Executability for transport: (0.8021610588161701, 0.8108194339372773)
# Balanced Executability for transport: (0.8021610588161701, 0.8108194339372773)
# Balanced Executability for transport: (0.8021610588161701, 0.8108194339372773)
# Balanced Executability for transport: (0.8021610588161701, 0.8108194339372773)
# Balanced Executability for transport: (0.8021610588161701, 0.8108194339372773)
# Balanced Executability for transport: (0.16203659056399042, 0.18210100625681877)
# Balanced Executability for transport: (0.8021610588161701, 0.8108194339372773)
# Balanced Executability for transport: (0.8021610588161701, 0.8108194339372773)
# Balanced Executability for transport: (0.8021610588161701, 0.8108194339372773)
# Balanced Executability for transport: (0.8021610588161701, 0.8108194339372773)
# Balanced Executability for transport: (0.16203659056399042, 0.18210100625681877)
# Balanced Executability for transport: (0.8021610588161701, 0.8108194339372773)
# Balanced Executability for transport: (0.8021610588161701, 0.8108194339372773)
# Balanced Executability for transport: (0.8021610588161701, 0.8108194339372773)
# Balanced Executability for transport: (0.16203659056399042, 0.18210100625681877)
# Balanced Executability for transport: (0.8021610588161701, 0.8108194339372773)
# Balanced Executability for transport: (0.8021610588161701, 0.8108194339372773)
# Balanced Executability for transport: (0.8021610588161701, 0.8108194339372773)
# Balanced Executability for transport: (0.16203659056399042, 0.18210100625681877)

# %%
# with open("../../data/plain_traces/plain_traces.txt", "r") as f:
#     with open("res.csv", "w") as out:
#         lines = f.readlines()
#         for line in lines:
#             try:
#                 details = line.split("&&")
#                 name = f"{details[0]}-{details[2]}-{details[3]}"
            
#                 plan = details[-1]
#                 trace = read_plan(plan)
           

#                 domain_name = details[0]
            
#                 exe_l, exe_gt = test_cross_exe(domain_name, trace, trace)
#             except Exception as e:
#                 print(f"Error processing task {name}: {e}")
#                 exe_l, exe_gt = 0, 0
#             print(f"Executability for {name}: {exe_l}, {exe_gt}")
#             out.write(f"{name},{exe_l}, {exe_gt}\n")
#             out.flush()

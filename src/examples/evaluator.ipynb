# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
from extract import LOCM2
from utils import read_plan, read_json_file
from evaluator import ExecutabilityEvaluator
from collections import defaultdict
import json

# %%
def test_cross_exe(domain_name, train_traces , prefix_traces, gt_traces=[],gen_seq_rate=None):
    debug = {}
    try:
        polocm2 = LOCM2(state_param=True, viz=False, debug=debug)
        model = polocm2.extract_model(train_traces)
        learned_domain = model.to_pddl_domain(domain_name)
        gt_filename = os.path.join('../../data', 'goose-benchmarks', 'tasks', domain_name, 'domain.pddl')
        
        evaluator = ExecutabilityEvaluator(learned_domain,gt_filename, debug=False)

        exe = evaluator.get_cross_executability(prefix_traces, gt_traces, gen_seq_rate)
        return exe
    except Exception as e:
        print(f"Error processing domain {domain_name}: {e}")
        return 0,0
    
def test_balanced_exe(domain_name,train_traces, test_traces, test_invalid_traces, binary=False):
    debug = {}
    try:
        polocm2 = LOCM2(state_param=True, viz=False, debug=debug)
        model = polocm2.extract_model(train_traces)
        learned_domain = model.to_pddl_domain(domain_name)
        gt_filename = os.path.join('../../data', 'goose-benchmarks', 'tasks', domain_name, 'domain.pddl')
        
        evaluator = ExecutabilityEvaluator(learned_domain, gt_filename, debug=False)
        exe = evaluator.get_balanced_executability(test_traces, test_invalid_traces, binary)

        return exe
    except Exception as e:
        print(f"Error processing domain {domain_name}: {e}")
        return 0,0

# %%
plain_traces = defaultdict(list)
with open("../../data/plain_traces/plain_traces.txt", "r") as f:
    lines = f.readlines()
    for line in lines:
        details = line.split("&&")

        domain_name = details[0]
        plan = details[-1]

        plain_traces[domain_name].append(read_plan(plan))

# %%
train_traces = defaultdict(list)
data = read_json_file("../../data/training_data/traces_plan_r1.json")
for learning_obj in data:
    domain_name = learning_obj["domain"]
    train_traces[domain_name].append(learning_obj)

# %%
valid_traces = defaultdict(list)
invalid_traces = defaultdict(list)

with open("../../data/plain_traces/random_walks.txt", "r") as f:
    lines = f.readlines()
    for line in lines:
        details = line.split("&&")
        domain_name = details[0]
        is_valid = details[1] == "rand"
        plan = details[-1]
        if is_valid:
            valid_traces[domain_name].append(read_plan(plan))
        else:
            invalid_traces[domain_name].append(read_plan(plan))

# %%
# with open("./cross_exe_results.csv", "w") as f:
#     f.write("ID, Domain, len, objs, l_exe, gt_exe\n")
#     for domain, items in train_traces.items():
#         print(f"Testing domain: {domain}")
#         for item in items:
#             traces = item["traces"]

#             try:
#                 coress_exe = test_cross_exe(domain, traces, plain_traces[domain], plain_traces[domain])
#             except Exception as e:
#                 print(f"Error in balanced executability for domain {domain}: {e}")
#                 coress_exe = 0,0

#         # Test balanced executability
#             f.write(f"{item['id']}, {domain}, {item['total_length']}, {item['number_of_objects']}, {coress_exe[0]}, {coress_exe[1]}\n")
#             f.flush()
#             print(f"Cross Executability for {domain}: {coress_exe}")

# %%
with open("./cross_exe_results.csv", "w") as f:
    f.write("ID, Domain, len, objs, gen_seq_rate, l_exe, gt_exe\n")
    for domain, items in train_traces.items():
        print(f"Testing domain: {domain}")
        for item in items:
            traces = item["traces"]
            for i in range(1, 11):
                gen_seq_rate = i / 10
                try:
                    coress_exe = test_cross_exe(domain, traces, plain_traces[domain], plain_traces[domain], gen_seq_rate=gen_seq_rate)
                except Exception as e:
                    print(f"Error in cross executability for domain {domain}: {e}")
                    coress_exe = 0,0

            # Test balanced executability
                f.write(f"{item['id']}, {domain}, {item['total_length']}, {item['number_of_objects']}, {gen_seq_rate}, {coress_exe[0]}, {coress_exe[1]}\n")
                f.flush()
                print(f"Cross Executability for {domain}: {coress_exe}")
# Out:
# Testing domain: blocksworld
# Cross Executability for blocksworld: (0.49481446543722457, 0.0)
# Cross Executability for blocksworld: (0.49481446543722457, 0.0)
# Cross Executability for blocksworld: (0.49481446543722457, 0.010526315789473684)
# Cross Executability for blocksworld: (0.49481446543722457, 0.010526315789473684)
# Cross Executability for blocksworld: (0.49481446543722457, 0.030303030303030304)
# Cross Executability for blocksworld: (0.49481446543722457, 0.029180695847362513)
# Cross Executability for blocksworld: (0.49481446543722457, 0.028058361391694726)
# Cross Executability for blocksworld: (0.49481446543722457, 0.030303030303030304)
# Cross Executability for blocksworld: (0.49481446543722457, 0.030303030303030304)
# Cross Executability for blocksworld: (0.49481446543722457, 0.030303030303030304)
# Cross Executability for blocksworld: (0.54726748531232, 0.9896067415730337)
# Cross Executability for blocksworld: (0.54726748531232, 0.9954855777436423)
# Cross Executability for blocksworld: (0.54726748531232, 0.9958479532163742)
# Cross Executability for blocksworld: (0.54726748531232, 0.9737426900584795)
# Cross Executability for blocksworld: (0.54726748531232, 0.4335016835016835)
# Cross Executability for blocksworld: (0.54726748531232, 0.0707070707070707)
# Cross Executability for blocksworld: (0.54726748531232, 0.06060606060606061)
# Cross Executability for blocksworld: (0.54726748531232, 0.06060606060606061)
# Cross Executability for blocksworld: (0.54726748531232, 0.06060606060606061)
# Cross Executability for blocksworld: (0.54726748531232, 0.06060606060606061)
# Cross Executability for blocksworld: (0.5893494360618644, 0.8112373165743952)
# Cross Executability for blocksworld: (0.5893494360618644, 0.8388310315729671)
# Cross Executability for blocksworld: (0.5893494360618644, 0.8578833544623019)
# Cross Executability for blocksworld: (0.5893494360618644, 0.8750864729812098)
# Cross Executability for blocksworld: (0.5893494360618644, 0.9198305809416921)
# Cross Executability for blocksworld: (0.5893494360618644, 0.9787317620650954)
# Cross Executability for blocksworld: (0.5893494360618644, 0.9913019079685746)
# Cross Executability for blocksworld: (0.5893494360618644, 0.9941077441077442)
# Cross Executability for blocksworld: (0.5893494360618644, 0.9932659932659933)
# Cross Executability for blocksworld: (0.5893494360618644, 0.9949494949494949)
# Cross Executability for blocksworld: (0.3736530849672458, 0.8320848938826467)
# Cross Executability for blocksworld: (0.3736530849672458, 0.8548387096774194)
# Cross Executability for blocksworld: (0.3736530849672458, 0.8385964912280702)
# Cross Executability for blocksworld: (0.3736530849672458, 0.8549707602339182)
# Cross Executability for blocksworld: (0.3736530849672458, 0.8333333333333334)
# Cross Executability for blocksworld: (0.3736530849672458, 0.8434343434343434)
# Cross Executability for blocksworld: (0.3736530849672458, 0.851290684624018)
# Cross Executability for blocksworld: (0.3736530849672458, 0.8400673400673401)
# Cross Executability for blocksworld: (0.3736530849672458, 0.8445566778900112)
# Cross Executability for blocksworld: (0.3736530849672458, 0.8310886644219978)
# Cross Executability for blocksworld: (0.5789783669363135, 0.6747993579454253)
# Cross Executability for blocksworld: (0.5789783669363135, 0.6760013085281903)
# Cross Executability for blocksworld: (0.5789783669363135, 0.6784809245335561)
# Cross Executability for blocksworld: (0.5789783669363135, 0.6735380116959064)
# Cross Executability for blocksworld: (0.5789783669363135, 0.6776695526695526)
# Cross Executability for blocksworld: (0.5789783669363135, 0.681377264710598)
# Cross Executability for blocksworld: (0.5789783669363135, 0.6858866442199776)
# Cross Executability for blocksworld: (0.5789783669363135, 0.6845839345839346)
# Cross Executability for blocksworld: (0.5789783669363135, 0.6793463737908182)
# Cross Executability for blocksworld: (0.5789783669363135, 0.6801881246325691)
# Cross Executability for blocksworld: (0.5789783669363135, 0.6714642411271625)
# Cross Executability for blocksworld: (0.5789783669363135, 0.678241451897366)
# Cross Executability for blocksworld: (0.5789783669363135, 0.6733430799220274)
# Cross Executability for blocksworld: (0.5789783669363135, 0.6809871901977166)
# Cross Executability for blocksworld: (0.5789783669363135, 0.6808227780450004)
# Cross Executability for blocksworld: (0.5789783669363135, 0.6875167014055903)
# Cross Executability for blocksworld: (0.5789783669363135, 0.6803217358772915)
# Cross Executability for blocksworld: (0.5789783669363135, 0.6800077494521939)
# Cross Executability for blocksworld: (0.5789783669363135, 0.6868018812463257)
# Cross Executability for blocksworld: (0.5789783669363135, 0.6778833306611085)
# Cross Executability for blocksworld: (0.5051855345627754, 1.0)
# Cross Executability for blocksworld: (0.5051855345627754, 1.0)
# Cross Executability for blocksworld: (0.5051855345627754, 0.9894736842105263)
# Cross Executability for blocksworld: (0.5051855345627754, 0.9894736842105263)
# Cross Executability for blocksworld: (0.5051855345627754, 0.9696969696969697)
# Cross Executability for blocksworld: (0.5051855345627754, 0.9696969696969697)
# Cross Executability for blocksworld: (0.5051855345627754, 0.9696969696969697)
# Cross Executability for blocksworld: (0.5051855345627754, 0.9696969696969697)
# Cross Executability for blocksworld: (0.5051855345627754, 0.9696969696969697)
# Cross Executability for blocksworld: (0.5051855345627754, 0.9696969696969697)
# Cross Executability for blocksworld: (0.5893494360618644, 0.8031810470012718)
# Cross Executability for blocksworld: (0.5893494360618644, 0.8525432850701669)
# Cross Executability for blocksworld: (0.5893494360618644, 0.8576617145038198)
# Cross Executability for blocksworld: (0.5893494360618644, 0.8688089493352651)
# Cross Executability for blocksworld: (0.5893494360618644, 0.9288319704986372)
# Cross Executability for blocksworld: (0.5893494360618644, 0.9871492704826038)
# Cross Executability for blocksworld: (0.5893494360618644, 0.9949494949494949)
# Cross Executability for blocksworld: (0.5893494360618644, 0.9949494949494949)
# Cross Executability for blocksworld: (0.5893494360618644, 0.9915824915824916)
# Cross Executability for blocksworld: (0.5893494360618644, 0.9941077441077442)
# Cross Executability for blocksworld: (0.5893494360618644, 0.8252700067306808)
# Cross Executability for blocksworld: (0.5893494360618644, 0.8486535368255799)
# Cross Executability for blocksworld: (0.5893494360618644, 0.8497218278797226)
# Cross Executability for blocksworld: (0.5893494360618644, 0.8631340686603844)
# Cross Executability for blocksworld: (0.5893494360618644, 0.9235209235209235)
# Cross Executability for blocksworld: (0.5893494360618644, 0.9875420875420876)
# Cross Executability for blocksworld: (0.5893494360618644, 0.9949494949494949)
# Cross Executability for blocksworld: (0.5893494360618644, 0.9966329966329966)
# Cross Executability for blocksworld: (0.5893494360618644, 0.9949494949494949)
# Cross Executability for blocksworld: (0.5893494360618644, 0.9957912457912458)
# Cross Executability for blocksworld: (0.3736530849672458, 0.8302122347066168)
# Cross Executability for blocksworld: (0.3736530849672458, 0.8327359617682198)
# Cross Executability for blocksworld: (0.3736530849672458, 0.8391812865497077)
# Cross Executability for blocksworld: (0.3736530849672458, 0.8362573099415205)
# Cross Executability for blocksworld: (0.3736530849672458, 0.8294051627384961)
# Cross Executability for blocksworld: (0.3736530849672458, 0.8484848484848485)
# Cross Executability for blocksworld: (0.3736530849672458, 0.8417508417508418)
# Cross Executability for blocksworld: (0.3736530849672458, 0.8322109988776656)
# Cross Executability for blocksworld: (0.3736530849672458, 0.8709315375982043)
# Cross Executability for blocksworld: (0.3736530849672458, 0.8524130190796858)
# Cross Executability for blocksworld: (0.5789783669363135, 0.6743282206765353)
# Cross Executability for blocksworld: (0.5789783669363135, 0.6680804460374353)
# Cross Executability for blocksworld: (0.5789783669363135, 0.6730158730158731)
# Cross Executability for blocksworld: (0.5789783669363135, 0.6746240601503759)
# Cross Executability for blocksworld: (0.5789783669363135, 0.6792996098551654)
# Cross Executability for blocksworld: (0.5789783669363135, 0.679727165838277)
# Cross Executability for blocksworld: (0.5789783669363135, 0.6856995884773662)
# Cross Executability for blocksworld: (0.5789783669363135, 0.6884653412431191)
# Cross Executability for blocksworld: (0.5789783669363135, 0.6896878841323286)
# Cross Executability for blocksworld: (0.5789783669363135, 0.6816444872000428)
# Cross Executability for blocksworld: (0.8188258265147725, 0.8742675328064238)
# Cross Executability for blocksworld: (0.8188258265147725, 0.8802018552592656)
# Cross Executability for blocksworld: (0.8188258265147725, 0.9011621911933084)
# Cross Executability for blocksworld: (0.8188258265147725, 0.9057801582038044)
# Cross Executability for blocksworld: (0.8188258265147725, 0.9259285243972901)
# Cross Executability for blocksworld: (0.8188258265147725, 0.9252231968922016)
# Cross Executability for blocksworld: (0.8188258265147725, 0.9318563481303801)
# Cross Executability for blocksworld: (0.8188258265147725, 0.9060333430755214)
# Cross Executability for blocksworld: (0.8188258265147725, 0.902747230896304)
# Cross Executability for blocksworld: (0.8188258265147725, 0.9033330834925363)
# Cross Executability for blocksworld: (1.0, 0.8761518448425617)
# Cross Executability for blocksworld: (1.0, 0.8748377592724123)
# Cross Executability for blocksworld: (1.0, 0.8992347643238717)
# Cross Executability for blocksworld: (1.0, 0.9104672307290101)
# Cross Executability for blocksworld: (1.0, 0.9321356302944133)
# Cross Executability for blocksworld: (1.0, 0.9310980177836797)
# Cross Executability for blocksworld: (1.0, 0.9403027262385644)
# Cross Executability for blocksworld: (1.0, 0.9455616070206173)
# Cross Executability for blocksworld: (1.0, 0.9367906522638829)
# Cross Executability for blocksworld: (1.0, 0.9840778516283567)
# Cross Executability for blocksworld: (1.0, 0.9599079219514396)
# Cross Executability for blocksworld: (1.0, 0.959115866656868)
# Cross Executability for blocksworld: (1.0, 0.9680374481396827)
# Cross Executability for blocksworld: (1.0, 0.9728776004383133)
# Cross Executability for blocksworld: (1.0, 0.9843959260577065)
# Cross Executability for blocksworld: (1.0, 0.988585540603657)
# Cross Executability for blocksworld: (1.0, 0.9857624743965878)
# Cross Executability for blocksworld: (1.0, 0.9944052354285762)
# Cross Executability for blocksworld: (1.0, 0.9652760451185882)
# Cross Executability for blocksworld: (1.0, 0.5948653198653199)
# Cross Executability for blocksworld: (0.5789783669363135, 0.6738942393436775)
# Cross Executability for blocksworld: (0.5789783669363135, 0.6718424645844001)
# Cross Executability for blocksworld: (0.5789783669363135, 0.66916597048176)
# Cross Executability for blocksworld: (0.5789783669363135, 0.6747145641882485)
# Cross Executability for blocksworld: (0.5789783669363135, 0.6871292287958956)
# Cross Executability for blocksworld: (0.5789783669363135, 0.6831542942654054)
# Cross Executability for blocksworld: (0.5789783669363135, 0.6773288439955107)
# Cross Executability for blocksworld: (0.5789783669363135, 0.6863476030142697)
# Cross Executability for blocksworld: (0.5789783669363135, 0.6757856341189675)
# Cross Executability for blocksworld: (0.5789783669363135, 0.6860736999625888)
# Cross Executability for blocksworld: (0.3736530849672458, 0.8320848938826467)
# Cross Executability for blocksworld: (0.3736530849672458, 0.8393070489844684)
# Cross Executability for blocksworld: (0.3736530849672458, 0.8380116959064328)
# Cross Executability for blocksworld: (0.3736530849672458, 0.8450292397660819)
# Cross Executability for blocksworld: (0.3736530849672458, 0.8400673400673401)
# Cross Executability for blocksworld: (0.3736530849672458, 0.8451178451178452)
# Cross Executability for blocksworld: (0.3736530849672458, 0.8400673400673401)
# Cross Executability for blocksworld: (0.3736530849672458, 0.8400673400673401)
# Cross Executability for blocksworld: (0.3736530849672458, 0.8546576879910214)
# Cross Executability for blocksworld: (0.3736530849672458, 0.8338945005611673)
# Cross Executability for blocksworld: (1.0, 0.9552807403114127)
# Cross Executability for blocksworld: (1.0, 0.9619108024706857)
# Cross Executability for blocksworld: (1.0, 0.9698892624511233)
# Cross Executability for blocksworld: (1.0, 0.9726562987640359)
# Cross Executability for blocksworld: (1.0, 0.9835053602990865)
# Cross Executability for blocksworld: (1.0, 0.9899282767169352)
# Cross Executability for blocksworld: (1.0, 0.9913736459965192)
# Cross Executability for blocksworld: (1.0, 0.9913054134954408)
# Cross Executability for blocksworld: (1.0, 0.9643767166791527)
# Cross Executability for blocksworld: (1.0, 0.5948051948051948)
# Cross Executability for blocksworld: (1.0, 0.9605331462086685)
# Cross Executability for blocksworld: (1.0, 0.9584259266299874)
# Cross Executability for blocksworld: (1.0, 0.9661239717262238)
# Cross Executability for blocksworld: (1.0, 0.9720200523028738)
# Cross Executability for blocksworld: (1.0, 0.980478777702294)
# Cross Executability for blocksworld: (1.0, 0.9854244590305106)
# Cross Executability for blocksworld: (1.0, 0.9874199144983397)
# Cross Executability for blocksworld: (1.0, 0.9901246949580248)
# Cross Executability for blocksworld: (1.0, 0.9652832317454546)
# Cross Executability for blocksworld: (1.0, 0.5937597165667341)
# Cross Executability for blocksworld: (1.0, 0.9579959274295242)
# Cross Executability for blocksworld: (1.0, 0.9630847122919168)
# Cross Executability for blocksworld: (1.0, 0.966764824672337)
# Cross Executability for blocksworld: (1.0, 0.9734517363184273)
# Cross Executability for blocksworld: (1.0, 0.9793962419785901)
# Cross Executability for blocksworld: (1.0, 0.9867903295131163)
# Cross Executability for blocksworld: (1.0, 0.9880833327656319)
# Cross Executability for blocksworld: (1.0, 0.9914999263877485)
# Cross Executability for blocksworld: (1.0, 0.9657616219633451)
# Cross Executability for blocksworld: (1.0, 0.5948372615039281)
# Cross Executability for blocksworld: (1.0, 0.7141661880105039)
# Cross Executability for blocksworld: (1.0, 0.7182873856729516)
# Cross Executability for blocksworld: (1.0, 0.7147135324641505)
# Cross Executability for blocksworld: (1.0, 0.7125943097192138)
# Cross Executability for blocksworld: (1.0, 0.7338274203603659)
# Cross Executability for blocksworld: (1.0, 0.7468583690973762)
# Cross Executability for blocksworld: (1.0, 0.7737376441426183)
# Cross Executability for blocksworld: (1.0, 0.7961905519820108)
# Cross Executability for blocksworld: (1.0, 0.8403820370217754)
# Cross Executability for blocksworld: (1.0, 0.9224525194222165)
# Cross Executability for blocksworld: (0.3736530849672458, 0.822721598002497)
# Cross Executability for blocksworld: (0.3736530849672458, 0.8219832735961768)
# Cross Executability for blocksworld: (0.3736530849672458, 0.8298245614035088)
# Cross Executability for blocksworld: (0.3736530849672458, 0.8298245614035088)
# Cross Executability for blocksworld: (0.3736530849672458, 0.8361391694725029)
# Cross Executability for blocksworld: (0.3736530849672458, 0.8569023569023569)
# Cross Executability for blocksworld: (0.3736530849672458, 0.8400673400673401)
# Cross Executability for blocksworld: (0.3736530849672458, 0.8434343434343434)
# Cross Executability for blocksworld: (0.3736530849672458, 0.8344556677890012)
# Cross Executability for blocksworld: (0.3736530849672458, 0.8316498316498316)
# Cross Executability for blocksworld: (1.0, 0.9617500497966285)
# Cross Executability for blocksworld: (1.0, 0.9579036436958527)
# Cross Executability for blocksworld: (1.0, 0.9731742783205032)
# Cross Executability for blocksworld: (1.0, 0.9735562130258341)
# Cross Executability for blocksworld: (1.0, 0.9795640773910397)
# Cross Executability for blocksworld: (1.0, 0.9896330253957788)
# Cross Executability for blocksworld: (1.0, 0.9891798381291966)
# Cross Executability for blocksworld: (1.0, 0.9924393829523309)
# Cross Executability for blocksworld: (1.0, 0.9639051594691587)
# Cross Executability for blocksworld: (1.0, 0.5954919566030678)
# Cross Executability for blocksworld: (1.0, 0.9584077616767418)
# Cross Executability for blocksworld: (1.0, 0.9594561724775474)
# Cross Executability for blocksworld: (1.0, 0.9728348802547968)
# Cross Executability for blocksworld: (1.0, 0.9738909154709033)
# Cross Executability for blocksworld: (1.0, 0.9821685734704488)
# Cross Executability for blocksworld: (1.0, 0.9884199150473075)
# Cross Executability for blocksworld: (1.0, 0.9875074709116218)
# Cross Executability for blocksworld: (1.0, 0.9935436561765942)
# Cross Executability for blocksworld: (1.0, 0.967911962764904)
# Cross Executability for blocksworld: (1.0, 0.5948773448773448)
# Cross Executability for blocksworld: (1.0, 0.9615245573404724)
# Cross Executability for blocksworld: (1.0, 0.9619204193836192)
# Cross Executability for blocksworld: (1.0, 0.9683159388270117)
# Cross Executability for blocksworld: (1.0, 0.9718521456470716)
# Cross Executability for blocksworld: (1.0, 0.9845419224047759)
# Cross Executability for blocksworld: (1.0, 0.9829749602167625)
# Cross Executability for blocksworld: (1.0, 0.9880946356987209)
# Cross Executability for blocksworld: (1.0, 0.9888349237766821)
# Cross Executability for blocksworld: (1.0, 0.965553428053428)
# Cross Executability for blocksworld: (1.0, 0.5944684944684945)
# Cross Executability for blocksworld: (0.3736530849672458, 0.822721598002497)
# Cross Executability for blocksworld: (0.3736530849672458, 0.8219832735961768)
# Cross Executability for blocksworld: (0.3736530849672458, 0.827485380116959)
# Cross Executability for blocksworld: (0.3736530849672458, 0.839766081871345)
# Cross Executability for blocksworld: (0.3736530849672458, 0.8535353535353535)
# Cross Executability for blocksworld: (0.3736530849672458, 0.8221099887766555)
# Cross Executability for blocksworld: (0.3736530849672458, 0.8479236812570147)
# Cross Executability for blocksworld: (0.3736530849672458, 0.8630751964085297)
# Cross Executability for blocksworld: (0.3736530849672458, 0.8294051627384961)
# Cross Executability for blocksworld: (0.3736530849672458, 0.8468013468013468)
# Cross Executability for blocksworld: (1.0, 0.9600349401610705)
# Cross Executability for blocksworld: (1.0, 0.9621375296874578)
# Cross Executability for blocksworld: (1.0, 0.9709075210975416)
# Cross Executability for blocksworld: (1.0, 0.9743435067986239)
# Cross Executability for blocksworld: (1.0, 0.9830966017192274)
# Cross Executability for blocksworld: (1.0, 0.98625438963433)
# Cross Executability for blocksworld: (1.0, 0.9874819154388084)
# Cross Executability for blocksworld: (1.0, 0.9916018924679362)
# Cross Executability for blocksworld: (1.0, 0.9660973972991204)
# Cross Executability for blocksworld: (1.0, 0.5952380952380952)
# Cross Executability for blocksworld: (1.0, 0.9621553511347809)
# Cross Executability for blocksworld: (1.0, 0.9615867629511208)
# Cross Executability for blocksworld: (1.0, 0.9716553995290124)
# Cross Executability for blocksworld: (1.0, 0.9704398901110839)
# Cross Executability for blocksworld: (1.0, 0.9802090035326183)
# Cross Executability for blocksworld: (1.0, 0.9858896960736431)
# Cross Executability for blocksworld: (1.0, 0.9891917431759654)
# Cross Executability for blocksworld: (1.0, 0.9931860691969598)
# Cross Executability for blocksworld: (1.0, 0.9659755788543667)
# Cross Executability for blocksworld: (1.0, 0.5957912457912458)
# Cross Executability for blocksworld: (1.0, 0.9568277415129866)
# Cross Executability for blocksworld: (1.0, 0.9623252125210324)
# Cross Executability for blocksworld: (1.0, 0.9683642581081675)
# Cross Executability for blocksworld: (1.0, 0.9733860197647399)
# Cross Executability for blocksworld: (1.0, 0.9828178076542066)
# Cross Executability for blocksworld: (1.0, 0.9878115575821365)
# Cross Executability for blocksworld: (1.0, 0.9859535369691325)
# Cross Executability for blocksworld: (1.0, 0.9937924958823334)
# Cross Executability for blocksworld: (1.0, 0.9651563099630732)
# Cross Executability for blocksworld: (1.0, 0.5959595959595959)
# Cross Executability for blocksworld: (0.3736530849672458, 0.8264669163545568)
# Cross Executability for blocksworld: (0.3736530849672458, 0.8470728793309439)
# Cross Executability for blocksworld: (0.3736530849672458, 0.8374269005847954)
# Cross Executability for blocksworld: (0.3736530849672458, 0.8245614035087719)
# Cross Executability for blocksworld: (0.3736530849672458, 0.8215488215488216)
# Cross Executability for blocksworld: (0.3736530849672458, 0.851290684624018)
# Cross Executability for blocksworld: (0.3736530849672458, 0.8462401795735129)
# Cross Executability for blocksworld: (0.3736530849672458, 0.8344556677890012)
# Cross Executability for blocksworld: (0.3736530849672458, 0.8439955106621774)
# Cross Executability for blocksworld: (0.3736530849672458, 0.8636363636363636)
# Testing domain: childsnack
# Cross Executability for childsnack: (0.6024334084283064, 0.0)
# Cross Executability for childsnack: (0.6024334084283064, 0.0)
# Cross Executability for childsnack: (0.6024334084283064, 0.0)
# Cross Executability for childsnack: (0.6024334084283064, 0.0)
# Cross Executability for childsnack: (0.6024334084283064, 0.0)
# Cross Executability for childsnack: (0.6024334084283064, 0.0)
# Cross Executability for childsnack: (0.6024334084283064, 0.0)
# Cross Executability for childsnack: (0.6024334084283064, 0.0)
# Cross Executability for childsnack: (0.6024334084283064, 0.0)
# Cross Executability for childsnack: (0.6024334084283064, 0.0)
# Cross Executability for childsnack: (0.8098048635038432, 0.8409090909090909)
# Cross Executability for childsnack: (0.8098048635038432, 0.8125)
# Cross Executability for childsnack: (0.8098048635038432, 0.8571428571428571)
# Cross Executability for childsnack: (0.8098048635038432, 0.8367346938775511)
# Cross Executability for childsnack: (0.8098048635038432, 0.8367346938775511)
# Cross Executability for childsnack: (0.8098048635038432, 0.8571428571428571)
# Cross Executability for childsnack: (0.8098048635038432, 0.8571428571428571)
# Cross Executability for childsnack: (0.8098048635038432, 0.8571428571428571)
# Cross Executability for childsnack: (0.8098048635038432, 0.8571428571428571)
# Cross Executability for childsnack: (0.8098048635038432, 0.8571428571428571)
# Cross Executability for childsnack: (0.7200781503077421, 1.0)
# Cross Executability for childsnack: (0.7200781503077421, 1.0)
# Cross Executability for childsnack: (0.7200781503077421, 1.0)
# Cross Executability for childsnack: (0.7200781503077421, 1.0)
# Cross Executability for childsnack: (0.7200781503077421, 1.0)
# Cross Executability for childsnack: (0.7200781503077421, 1.0)
# Cross Executability for childsnack: (0.7200781503077421, 1.0)
# Cross Executability for childsnack: (0.7200781503077421, 1.0)
# Cross Executability for childsnack: (0.7200781503077421, 1.0)
# Cross Executability for childsnack: (0.7200781503077421, 1.0)
# Cross Executability for childsnack: (0.3633523034033238, 0.8409090909090909)
# Cross Executability for childsnack: (0.3633523034033238, 0.8125)
# Cross Executability for childsnack: (0.3633523034033238, 0.8163265306122449)
# Cross Executability for childsnack: (0.3633523034033238, 0.8163265306122449)
# Cross Executability for childsnack: (0.3633523034033238, 0.8163265306122449)
# Cross Executability for childsnack: (0.3633523034033238, 0.8163265306122449)
# Cross Executability for childsnack: (0.3633523034033238, 0.8163265306122449)
# Cross Executability for childsnack: (0.3633523034033238, 0.8163265306122449)
# Cross Executability for childsnack: (0.3633523034033238, 0.8163265306122449)
# Cross Executability for childsnack: (0.3633523034033238, 0.8163265306122449)
# Cross Executability for childsnack: (0.6610793307221878, 0.8409090909090909)
# Cross Executability for childsnack: (0.6610793307221878, 0.8125)
# Cross Executability for childsnack: (0.6610793307221878, 0.8571428571428571)
# Cross Executability for childsnack: (0.6610793307221878, 0.8367346938775511)
# Cross Executability for childsnack: (0.6610793307221878, 0.8163265306122449)
# Cross Executability for childsnack: (0.6610793307221878, 0.8163265306122449)
# Cross Executability for childsnack: (0.6610793307221878, 0.826530612244898)
# Cross Executability for childsnack: (0.6610793307221878, 0.8367346938775511)
# Cross Executability for childsnack: (0.6610793307221878, 0.8367346938775511)
# Cross Executability for childsnack: (0.6610793307221878, 0.8367346938775511)
# Cross Executability for childsnack: (0.7827155176644973, 1.0)
# Cross Executability for childsnack: (0.7827155176644973, 1.0)
# Cross Executability for childsnack: (0.7827155176644973, 1.0)
# Cross Executability for childsnack: (0.7827155176644973, 1.0)
# Cross Executability for childsnack: (0.7827155176644973, 0.9693877551020408)
# Cross Executability for childsnack: (0.7827155176644973, 0.8015873015873015)
# Cross Executability for childsnack: (0.7827155176644973, 0.9158163265306123)
# Cross Executability for childsnack: (0.7827155176644973, 0.9297619047619048)
# Cross Executability for childsnack: (0.7827155176644973, 0.9309523809523809)
# Cross Executability for childsnack: (0.7827155176644973, 0.9284580498866212)
# Cross Executability for childsnack: (0.5709157905586477, 1.0)
# Cross Executability for childsnack: (0.5709157905586477, 1.0)
# Cross Executability for childsnack: (0.5709157905586477, 1.0)
# Cross Executability for childsnack: (0.5709157905586477, 1.0)
# Cross Executability for childsnack: (0.5709157905586477, 1.0)
# Cross Executability for childsnack: (0.5709157905586477, 1.0)
# Cross Executability for childsnack: (0.5709157905586477, 1.0)
# Cross Executability for childsnack: (0.5709157905586477, 1.0)
# Cross Executability for childsnack: (0.5709157905586477, 1.0)

# %%
# with open("./balanced_exe_results.csv", "w") as f:
#     f.write("ID, Domain, len, objs, valid_exe, invalid_exe\n")
#     for domain, items in train_traces.items():
#         print(f"Testing domain: {domain}")
#         for item in items:
#             traces = item["traces"]

#             try:
#                 balanced_exe = test_balanced_exe(domain, traces, valid_traces[domain], invalid_traces[domain])
#             except Exception as e:
#                 print(f"Error in balanced executability for domain {domain}: {e}")
#                 balanced_exe = 0,0

#         # Test balanced executability
#             f.write(f"{item['id']}, {domain}, {item['total_length']}, {item['number_of_objects']}, {balanced_exe[0]}, {balanced_exe[1]}\n")
#             f.flush()
#             print(f"Balanced Executability for {domain}: {balanced_exe}")

# %%
# with open("./balanced_binary_exe_results.csv", "w") as f:
#     f.write("ID, Domain, len, objs, valid_exe, invalid_exe\n")
#     for domain, items in train_traces.items():
#         print(f"Testing domain: {domain}")
#         for item in items:
#             traces = item["traces"]

#             try:
#                 balanced_exe = test_balanced_exe(domain, traces, valid_traces[domain], invalid_traces[domain], binary=True)
#             except Exception as e:
#                 print(f"Error in balanced executability for domain {domain}: {e}")
#                 balanced_exe = 0,0

#         # Test balanced executability
#             f.write(f"{item['id']}, {domain}, {item['total_length']}, {item['number_of_objects']}, {balanced_exe[0]}, {balanced_exe[1]}\n")
#             f.flush()
#             print(f"Balanced Executability for {domain}: {balanced_exe}")
# Out:
# Testing domain: blocksworld
# Balanced Executability for blocksworld: (0.15850073419758487, 0.9993265993265993)
# Balanced Executability for blocksworld: (0.2333423618833991, 0.9966329966329966)
# Balanced Executability for blocksworld: (0.28044776143401734, 0.9837037037037037)
# Balanced Executability for blocksworld: (0.1953716950739421, 0.9858585858585859)
# Balanced Executability for blocksworld: (0.2445116775437157, 0.9827609427609428)
# Balanced Executability for blocksworld: (0.2445116775437157, 0.9827609427609428)
# Balanced Executability for blocksworld: (0.19686526926633768, 0.9986531986531986)
# Balanced Executability for blocksworld: (0.28044776143401734, 0.9837037037037037)
# Balanced Executability for blocksworld: (0.28044776143401734, 0.9837037037037037)
# Balanced Executability for blocksworld: (0.1953716950739421, 0.9858585858585859)
# Balanced Executability for blocksworld: (0.28554283604900293, 0.9827609427609428)
# Balanced Executability for blocksworld: (0.41375391405604867, 0.9835690235690235)
# Balanced Executability for blocksworld: (0.4053790819944305, 0.9819528619528619)
# Balanced Executability for blocksworld: (0.4294065375510209, 0.9854545454545455)
# Balanced Executability for blocksworld: (0.2445116775437157, 0.9827609427609428)
# Balanced Executability for blocksworld: (0.1953716950739421, 0.9858585858585859)
# Balanced Executability for blocksworld: (0.4453188787126932, 0.9854545454545455)
# Balanced Executability for blocksworld: (0.4113752384424625, 0.9854545454545455)
# Balanced Executability for blocksworld: (0.4671028675115175, 0.9854545454545455)
# Balanced Executability for blocksworld: (0.44158093133877063, 0.9815488215488216)
# Balanced Executability for blocksworld: (0.1953716950739421, 0.9858585858585859)
# Balanced Executability for blocksworld: (0.4453188787126932, 0.9854545454545455)
# Balanced Executability for blocksworld: (0.4671028675115175, 0.9854545454545455)
# Balanced Executability for blocksworld: (0.4453188787126932, 0.9854545454545455)
# Balanced Executability for blocksworld: (0.1953716950739421, 0.9858585858585859)
# Balanced Executability for blocksworld: (0.4453188787126932, 0.9854545454545455)
# Balanced Executability for blocksworld: (0.4671028675115175, 0.9854545454545455)
# Balanced Executability for blocksworld: (0.4453188787126932, 0.9854545454545455)
# Balanced Executability for blocksworld: (0.1953716950739421, 0.9858585858585859)
# Testing domain: childsnack
# Balanced Executability for childsnack: (0.4347991332175006, 1.0)
# Balanced Executability for childsnack: (0.5207996878405041, 0.9983673469387755)
# Balanced Executability for childsnack: (0.5808313946069048, 1.0)
# Balanced Executability for childsnack: (0.2569170323251956, 1.0)
# Balanced Executability for childsnack: (0.293791817592838, 1.0)
# Balanced Executability for childsnack: (0.44369194864092826, 1.0)
# Balanced Executability for childsnack: (0.4803173192076253, 1.0)
# Balanced Executability for childsnack: (0.49540925533272473, 1.0)
# Balanced Executability for childsnack: (0.5808313946069048, 1.0)
# Balanced Executability for childsnack: (0.2569170323251956, 1.0)
# Balanced Executability for childsnack: (0.7140536867705235, 0.996734693877551)
# Balanced Executability for childsnack: (0.7140536867705235, 0.996734693877551)
# Balanced Executability for childsnack: (0.7253727753727753, 0.9983673469387755)
# Balanced Executability for childsnack: (0.7253727753727753, 0.9983673469387755)
# Balanced Executability for childsnack: (0.7253727753727753, 0.9983673469387755)
# Balanced Executability for childsnack: (0.2569170323251956, 1.0)
# Balanced Executability for childsnack: (0.6607959024158003, 0.9983673469387755)
# Balanced Executability for childsnack: (0.7253727753727753, 0.9983673469387755)
# Balanced Executability for childsnack: (0.7253727753727753, 0.9983673469387755)
# Balanced Executability for childsnack: (0.7253727753727753, 0.9983673469387755)
# Balanced Executability for childsnack: (0.2569170323251956, 1.0)
# Balanced Executability for childsnack: (0.7253727753727753, 0.9983673469387755)
# Balanced Executability for childsnack: (0.7253727753727753, 0.9983673469387755)
# Balanced Executability for childsnack: (0.7253727753727753, 0.9983673469387755)
# Balanced Executability for childsnack: (0.2569170323251956, 1.0)
# Balanced Executability for childsnack: (0.7253727753727753, 0.9983673469387755)
# Balanced Executability for childsnack: (0.7253727753727753, 0.9983673469387755)
# Balanced Executability for childsnack: (0.7253727753727753, 0.9983673469387755)
# Balanced Executability for childsnack: (0.2569170323251956, 1.0)
# Testing domain: ferry
# Balanced Executability for ferry: (0.2527733889395089, 1.0)
# Balanced Executability for ferry: (0.260590355143869, 1.0)
# Balanced Executability for ferry: (0.2527733889395089, 1.0)
# Balanced Executability for ferry: (0.18721792880167892, 1.0)
# Balanced Executability for ferry: (0.9166416321303616, 0.9741496839742454)
# Balanced Executability for ferry: (0.2527733889395089, 1.0)
# Balanced Executability for ferry: (0.260590355143869, 1.0)
# Balanced Executability for ferry: (0.260590355143869, 1.0)
# Balanced Executability for ferry: (0.2527733889395089, 1.0)
# Balanced Executability for ferry: (0.18721792880167892, 1.0)
# Balanced Executability for ferry: (0.9166416321303616, 0.9741496839742454)
# Balanced Executability for ferry: (0.260590355143869, 1.0)
# Balanced Executability for ferry: (0.9852426183020898, 0.941143650442257)
# Balanced Executability for ferry: (0.260590355143869, 1.0)
# Balanced Executability for ferry: (0.9852426183020898, 0.941143650442257)
# Balanced Executability for ferry: (0.18721792880167892, 1.0)
# Balanced Executability for ferry: (0.9852426183020898, 0.941143650442257)
# Balanced Executability for ferry: (0.9852426183020898, 0.941143650442257)
# Balanced Executability for ferry: (0.260590355143869, 1.0)
# Balanced Executability for ferry: (0.9852426183020898, 0.941143650442257)
# Balanced Executability for ferry: (0.18721792880167892, 1.0)
# Balanced Executability for ferry: (0.9852426183020898, 0.941143650442257)
# Balanced Executability for ferry: (0.9852426183020898, 0.941143650442257)
# Balanced Executability for ferry: (0.9852426183020898, 0.941143650442257)
# Balanced Executability for ferry: (0.18721792880167892, 1.0)
# Balanced Executability for ferry: (0.9852426183020898, 0.941143650442257)
# Balanced Executability for ferry: (0.9852426183020898, 0.941143650442257)
# Balanced Executability for ferry: (0.9852426183020898, 0.941143650442257)
# Balanced Executability for ferry: (0.18721792880167892, 1.0)
# Testing domain: floortile
# Balanced Executability for floortile: (0.10321982891333326, 1.0)
# Balanced Executability for floortile: (0.13338380920190018, 1.0)
# Balanced Executability for floortile: (0.14326456405399723, 1.0)
# Balanced Executability for floortile: (0.136646907871654, 1.0)
# Balanced Executability for floortile: (0.1548865014684614, 1.0)
# Balanced Executability for floortile: (0.1385777592998317, 1.0)
# Balanced Executability for floortile: (0.1257323440099658, 1.0)
# Balanced Executability for floortile: (0.1548865014684614, 1.0)
# Balanced Executability for floortile: (0.1470700132082694, 1.0)
# Balanced Executability for floortile: (0.1503331118780232, 1.0)
# Balanced Executability for floortile: (0.1576862863208838, 1.0)
# Balanced Executability for floortile: (0.14797553647565584, 1.0)
# Balanced Executability for floortile: (0.1498053098317664, 1.0)
# Balanced Executability for floortile: (0.1592200182488379, 1.0)
# Balanced Executability for floortile: (0.15040598999378826, 1.0)
# Balanced Executability for floortile: (0.1503331118780232, 1.0)
# Balanced Executability for floortile: (0.1778752110496517, 1.0)
# Balanced Executability for floortile: (0.1453247983570933, 1.0)
# Balanced Executability for floortile: (0.1498053098317664, 1.0)
# Balanced Executability for floortile: (0.150809111100368, 1.0)
# Balanced Executability for floortile: (0.1503331118780232, 1.0)
# Balanced Executability for floortile: (0.1453247983570933, 1.0)
# Balanced Executability for floortile: (0.1453247983570933, 1.0)
# Balanced Executability for floortile: (0.1518762955414995, 1.0)
# Balanced Executability for floortile: (0.1503331118780232, 1.0)
# Balanced Executability for floortile: (0.20745897627920276, 1.0)
# Balanced Executability for floortile: (0.15901100236346255, 1.0)
# Balanced Executability for floortile: (0.2092833897320285, 1.0)
# Balanced Executability for floortile: (0.1503331118780232, 1.0)
# Testing domain: miconic
# Balanced Executability for miconic: (0.4080328345625112, 1.0)
# Balanced Executability for miconic: (0.5661568344609896, 0.9952020202020202)
# Balanced Executability for miconic: (0.4086656932324093, 0.9991919191919192)
# Balanced Executability for miconic: (0.29173154324976125, 0.9984848484848485)
# Balanced Executability for miconic: (0.6489258953690287, 0.9952020202020202)
# Balanced Executability for miconic: (0.19915024108398222, 1.0)
# Balanced Executability for miconic: (0.5769368506356042, 0.9952020202020202)
# Balanced Executability for miconic: (0.7250609816128881, 0.9944444444444445)
# Balanced Executability for miconic: (0.19624926216816505, 1.0)
# Balanced Executability for miconic: (0.29173154324976125, 0.9984848484848485)
# Balanced Executability for miconic: (0.6489258953690287, 0.9952020202020202)
# Balanced Executability for miconic: (0.19915024108398222, 1.0)
# Balanced Executability for miconic: (0.7250609816128881, 0.9944444444444445)
# Balanced Executability for miconic: (0.7250609816128881, 0.9944444444444445)
# Balanced Executability for miconic: (0.5753166864444271, 0.9968181818181817)
# Balanced Executability for miconic: (0.29173154324976125, 0.9984848484848485)
# Balanced Executability for miconic: (0.6489258953690287, 0.9952020202020202)
# Balanced Executability for miconic: (0.7250609816128881, 0.9944444444444445)
# Balanced Executability for miconic: (0.8386507464692472, 0.9859636771757985)
# Balanced Executability for miconic: (0.5753166864444271, 0.9968181818181817)
# Balanced Executability for miconic: (0.29173154324976125, 0.9984848484848485)
# Balanced Executability for miconic: (0.7250609816128881, 0.9944444444444445)
# Balanced Executability for miconic: (0.8386507464692472, 0.9859636771757985)
# Balanced Executability for miconic: (0.5753166864444271, 0.9968181818181817)
# Balanced Executability for miconic: (0.29173154324976125, 0.9984848484848485)
# Balanced Executability for miconic: (0.7250609816128881, 0.9944444444444445)
# Balanced Executability for miconic: (0.8386507464692472, 0.9859636771757985)
# Balanced Executability for miconic: (0.5753166864444271, 0.9968181818181817)
# Balanced Executability for miconic: (0.29173154324976125, 0.9984848484848485)
# Testing domain: rovers
# Balanced Executability for rovers: (0.1666599267323572, 1.0)
# Balanced Executability for rovers: (0.30278494400577743, 0.9938584984039529)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Balanced Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Balanced Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Balanced Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Balanced Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Balanced Executability for rovers: (0, 0)
# Balanced Executability for rovers: (0.24468433907875412, 1.0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Balanced Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Balanced Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Balanced Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Balanced Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Balanced Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Balanced Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Balanced Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Balanced Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Balanced Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Balanced Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Balanced Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Balanced Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Balanced Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Balanced Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Balanced Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Balanced Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Balanced Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Balanced Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Balanced Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Balanced Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Balanced Executability for rovers: (0, 0)
# Testing domain: satellite
# Balanced Executability for satellite: (0.06981546876982055, 1.0)
# Balanced Executability for satellite: (0.09532484777841403, 1.0)
# Balanced Executability for satellite: (0.10923211285003857, 0.9991341991341991)
# Balanced Executability for satellite: (0.06972693819998663, 1.0)
# Balanced Executability for satellite: (0.08186224881409145, 1.0)
# Balanced Executability for satellite: (0.08712651864341547, 1.0)
# Balanced Executability for satellite: (0.5371813402670391, 0.9964502164502165)
# Balanced Executability for satellite: (0.054387614325854206, 1.0)
# Balanced Executability for satellite: (0.12920686746068924, 1.0)
# Balanced Executability for satellite: (0.06972693819998663, 1.0)
# Balanced Executability for satellite: (0.0840973215555902, 1.0)
# Balanced Executability for satellite: (0.07268590235001687, 1.0)
# Balanced Executability for satellite: (0.355911302799082, 1.0)
# Balanced Executability for satellite: (0.355911302799082, 1.0)
# Balanced Executability for satellite: (0.9321277967389989, 0.9867136754176364)
# Balanced Executability for satellite: (0.06972693819998663, 1.0)
# Balanced Executability for satellite: (0.09300327493725095, 1.0)
# Balanced Executability for satellite: (0.4803573507616205, 0.9982363315696648)
# Balanced Executability for satellite: (0.3583663936708036, 1.0)
# Balanced Executability for satellite: (0.4699360231538847, 0.9982363315696648)
# Balanced Executability for satellite: (0.06972693819998663, 1.0)
# Balanced Executability for satellite: (0.9321277967389989, 0.9867136754176364)
# Balanced Executability for satellite: (0.4803573507616205, 0.9982363315696648)
# Balanced Executability for satellite: (0.4803573507616205, 0.9982363315696648)
# Balanced Executability for satellite: (0.06972693819998663, 1.0)
# Balanced Executability for satellite: (0.4803573507616205, 0.9982363315696648)
# Balanced Executability for satellite: (0.9321277967389989, 0.9867136754176364)
# Balanced Executability for satellite: (0.4803573507616205, 0.9982363315696648)
# Balanced Executability for satellite: (0.06972693819998663, 1.0)
# Testing domain: sokoban
# Balanced Executability for sokoban: (0.3830017847438288, 0.993395061728395)
# Balanced Executability for sokoban: (0.5455733001743981, 0.98334455667789)
# Balanced Executability for sokoban: (0.5455733001743981, 0.98334455667789)
# Balanced Executability for sokoban: (0.12780875755481116, 0.9992424242424243)
# Balanced Executability for sokoban: (0.7881802437605544, 0.9076209771515382)
# Balanced Executability for sokoban: (0.2095432357568039, 0.9992424242424243)
# Balanced Executability for sokoban: (0.963583745114337, 0.5864217638865018)
# Balanced Executability for sokoban: (0.7881802437605544, 0.9108027953333563)
# Balanced Executability for sokoban: (0.7881802437605544, 0.9108027953333563)
# Balanced Executability for sokoban: (0.12780875755481116, 0.9992424242424243)
# Balanced Executability for sokoban: (0.9998462765985859, 0.32799695516167526)
# Balanced Executability for sokoban: (0.2095432357568039, 0.9992424242424243)
# Balanced Executability for sokoban: (0.963583745114337, 0.5864217638865018)
# Balanced Executability for sokoban: (1.0, 0.3304028814607503)
# Balanced Executability for sokoban: (1.0, 0.3304028814607503)
# Balanced Executability for sokoban: (0.12780875755481116, 0.9992424242424243)
# Balanced Executability for sokoban: (0.9998462765985859, 0.32799695516167526)
# Balanced Executability for sokoban: (0.963583745114337, 0.5864217638865018)
# Balanced Executability for sokoban: (1.0, 0.3304028814607503)
# Balanced Executability for sokoban: (1.0, 0.3304028814607503)
# Balanced Executability for sokoban: (0.12780875755481116, 0.9992424242424243)
# Balanced Executability for sokoban: (0.963583745114337, 0.5864217638865018)
# Balanced Executability for sokoban: (1.0, 0.3304028814607503)
# Balanced Executability for sokoban: (1.0, 0.3304028814607503)
# Balanced Executability for sokoban: (0.12780875755481116, 0.9992424242424243)
# Balanced Executability for sokoban: (0.963583745114337, 0.5864217638865018)
# Balanced Executability for sokoban: (1.0, 0.3304028814607503)
# Balanced Executability for sokoban: (1.0, 0.3304028814607503)
# Balanced Executability for sokoban: (0.12780875755481116, 0.9992424242424243)
# Testing domain: spanner
# Balanced Executability for spanner: (0.7204377791555583, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (0.8903378717192332, 1.0)
# Balanced Executability for spanner: (0.9095774362231731, 1.0)
# Balanced Executability for spanner: (0.8903378717192332, 1.0)
# Balanced Executability for spanner: (0.8903378717192332, 1.0)
# Balanced Executability for spanner: (0.9095774362231731, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (0.9095774362231731, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (0.8903378717192332, 1.0)
# Balanced Executability for spanner: (0.9095774362231731, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (0.9095774362231731, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (0.9095774362231731, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (0.9095774362231731, 1.0)
# Balanced Executability for spanner: (0.9095774362231731, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (0.9095774362231731, 1.0)
# Balanced Executability for spanner: (0.9095774362231731, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (0.9095774362231731, 1.0)
# Testing domain: transport
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.33900164528645016, 1.0)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.16203659056399042, 1.0)
# Balanced Executability for transport: (0.7929520743549477, 0.9899054032387365)
# Balanced Executability for transport: (0.7929520743549477, 0.9899054032387365)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.16203659056399042, 1.0)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.16203659056399042, 1.0)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.16203659056399042, 1.0)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.16203659056399042, 1.0)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.16203659056399042, 1.0)

# %%
# with open("../../data/plain_traces/plain_traces.txt", "r") as f:
#     with open("res.csv", "w") as out:
#         lines = f.readlines()
#         for line in lines:
#             try:
#                 details = line.split("&&")
#                 name = f"{details[0]}-{details[2]}-{details[3]}"
            
#                 plan = details[-1]
#                 trace = read_plan(plan)
           

#                 domain_name = details[0]
            
#                 exe_l, exe_gt = test_cross_exe(domain_name, trace, trace)
#             except Exception as e:
#                 print(f"Error processing task {name}: {e}")
#                 exe_l, exe_gt = 0, 0
#             print(f"Executability for {name}: {exe_l}, {exe_gt}")
#             out.write(f"{name},{exe_l}, {exe_gt}\n")
#             out.flush()

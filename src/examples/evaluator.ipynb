# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
from extract import LOCM2
from utils import read_plan, read_json_file
from evaluator import ExecutabilityEvaluator
from collections import defaultdict
import json

# %%
def test_cross_exe(domain_name, train_traces , prefix_traces, gt_traces=[],gen_seq_rate=None):
    debug = {}
    try:
        polocm2 = LOCM2(state_param=True, viz=False, debug=debug)
        model = polocm2.extract_model(train_traces)
        learned_domain = model.to_pddl_domain(domain_name)
        gt_filename = os.path.join('../../data', 'goose-benchmarks', 'tasks', domain_name, 'domain.pddl')
        
        evaluator = ExecutabilityEvaluator(learned_domain,gt_filename, debug=False)

        exe = evaluator.get_cross_executability(prefix_traces, gt_traces, gen_seq_rate)
        return exe
    except Exception as e:
        print(f"Error processing domain {domain_name}: {e}")
        return 0,0
    
def test_balanced_exe(domain_name,train_traces, test_traces, test_invalid_traces, binary=False):
    debug = {}
    try:
        polocm2 = LOCM2(state_param=True, viz=False, debug=debug)
        model = polocm2.extract_model(train_traces)
        learned_domain = model.to_pddl_domain(domain_name)
        gt_filename = os.path.join('../../data', 'goose-benchmarks', 'tasks', domain_name, 'domain.pddl')
        
        evaluator = ExecutabilityEvaluator(learned_domain, gt_filename, debug=False)
        exe = evaluator.get_balanced_executability(test_traces, test_invalid_traces, binary)

        return exe
    except Exception as e:
        print(f"Error processing domain {domain_name}: {e}")
        return 0,0

# %%
plain_traces = defaultdict(list)
with open("../../data/plain_traces/plain_traces.txt", "r") as f:
    lines = f.readlines()
    for line in lines:
        details = line.split("&&")

        domain_name = details[0]
        plan = details[-1]

        plain_traces[domain_name].append(read_plan(plan))

# %%
train_traces = defaultdict(list)
data = read_json_file("../../data/training_data/traces_plan_r5.json")
for learning_obj in data:
    domain_name = learning_obj["domain"]
    train_traces[domain_name].append(learning_obj)

# %%
valid_traces = defaultdict(list)
invalid_traces = defaultdict(list)

with open("../../data/plain_traces/random_walks.txt", "r") as f:
    lines = f.readlines()
    for line in lines:
        details = line.split("&&")
        domain_name = details[0]
        is_valid = details[1] == "rand"
        plan = details[-1]
        if is_valid:
            valid_traces[domain_name].append(read_plan(plan))
        else:
            invalid_traces[domain_name].append(read_plan(plan))

# %%
# with open("./cross_exe.csv", "w") as f:
#     f.write("ID, Domain, len, len%, l_exe, gt_exe\n")
#     for domain, items in train_traces.items():
#         print(f"Testing domain: {domain}")
#         for item in items:
#             traces = item["traces"]

#             try:
#                 coress_exe = test_cross_exe(domain, traces, plain_traces[domain], plain_traces[domain])
#             except Exception as e:
#                 print(f"Error in balanced executability for domain {domain}: {e}")
#                 coress_exe = 0,0

#         # Test balanced executability
#             f.write(f"{item['id']}, {domain}, {item['total_length']}, {item['len%']}, {coress_exe[0]}, {coress_exe[1]}\n")
#             f.flush()
#             print(f"Cross Executability for {domain}: {coress_exe}")

# %%
with open("./cross_exe.csv", "w") as f:
    f.write("ID, Domain, len, objs, gen_seq_rate, l_exe, gt_exe\n")
    for domain, items in train_traces.items():
        print(f"Testing domain: {domain}")
        for item in items:
            traces = item["traces"]
            for i in range(1, 11):
                gen_seq_rate = i / 10
                try:
                    coress_exe = test_cross_exe(domain, traces, plain_traces[domain], plain_traces[domain], gen_seq_rate=gen_seq_rate)
                except Exception as e:
                    print(f"Error in cross executability for domain {domain}: {e}")
                    coress_exe = 0,0

            # Test balanced executability
                f.write(f"{item['id']}, {domain}, {item['total_length']}, {item['number_of_objects']}, {gen_seq_rate}, {coress_exe[0]}, {coress_exe[1]}\n")
                f.flush()
                print(f"Cross Executability for {domain}: {coress_exe}")

# %%
# with open("./balanced_exe.csv", "w") as f:
#     f.write("ID, Domain, len, objs, valid_exe, invalid_exe\n")
#     for domain, items in train_traces.items():
#         print(f"Testing domain: {domain}")
#         for item in items:
#             traces = item["traces"]

#             try:
#                 balanced_exe = test_balanced_exe(domain, traces, valid_traces[domain], invalid_traces[domain])
#             except Exception as e:
#                 print(f"Error in balanced executability for domain {domain}: {e}")
#                 balanced_exe = 0,0

#         # Test balanced executability
#             f.write(f"{item['id']}, {domain}, {item['total_length']}, {item['number_of_objects']}, {balanced_exe[0]}, {balanced_exe[1]}\n")
#             f.flush()
#             print(f"Balanced Executability for {domain}: {balanced_exe}")

# %%
with open("./balanced_binary_exe.csv", "w") as f:
    f.write("ID, Domain, len, len%, valid_exe, invalid_exe\n")
    for domain, items in train_traces.items():
        print(f"Testing domain: {domain}")
        for item in items:
            traces = item["traces"]

            try:
                balanced_exe = test_balanced_exe(domain, traces, valid_traces[domain], invalid_traces[domain], binary=True)
            except Exception as e:
                print(f"Error in balanced executability for domain {domain}: {e}")
                balanced_exe = 0,0

        # Test balanced executability
            f.write(f"{item['id']}, {domain}, {item['total_length']}, {item['len%']}, {balanced_exe[0]}, {balanced_exe[1]}\n")
            f.flush()
            print(f"Balanced Executability for {domain}: {balanced_exe}")
# Out:
# Testing domain: blocksworld
# Balanced Executability for blocksworld: (0.19686526926633768, 0.9986531986531986)
# Balanced Executability for blocksworld: (0.28513642468396816, 0.9885521885521885)
# Balanced Executability for blocksworld: (0.19686526926633768, 0.9986531986531986)
# Balanced Executability for blocksworld: (0.19686526926633768, 0.9986531986531986)
# Balanced Executability for blocksworld: (0.19686526926633768, 0.9986531986531986)
# Balanced Executability for blocksworld: (0.19686526926633768, 0.9986531986531986)
# Balanced Executability for blocksworld: (0.28044776143401734, 0.9837037037037037)
# Balanced Executability for blocksworld: (0.28044776143401734, 0.9837037037037037)
# Balanced Executability for blocksworld: (0.28044776143401734, 0.9837037037037037)
# Balanced Executability for blocksworld: (0.19686526926633768, 0.9986531986531986)
# Balanced Executability for blocksworld: (0.19686526926633768, 0.9986531986531986)
# Balanced Executability for blocksworld: (0.19686526926633768, 0.9986531986531986)
# Balanced Executability for blocksworld: (0.19686526926633768, 0.9986531986531986)
# Balanced Executability for blocksworld: (0.28044776143401734, 0.9837037037037037)
# Balanced Executability for blocksworld: (0.28044776143401734, 0.9837037037037037)
# Balanced Executability for blocksworld: (0.28044776143401734, 0.9837037037037037)
# Balanced Executability for blocksworld: (0.28044776143401734, 0.9837037037037037)
# Balanced Executability for blocksworld: (0.19686526926633768, 0.9986531986531986)
# Balanced Executability for blocksworld: (0.19686526926633768, 0.9986531986531986)
# Balanced Executability for blocksworld: (0.19686526926633768, 0.9986531986531986)
# Balanced Executability for blocksworld: (0.28044776143401734, 0.9837037037037037)
# Balanced Executability for blocksworld: (0.3743502810523842, 0.983030303030303)
# Balanced Executability for blocksworld: (0.40513898181553243, 0.9854545454545455)
# Balanced Executability for blocksworld: (0.28044776143401734, 0.9837037037037037)
# Balanced Executability for blocksworld: (0.28044776143401734, 0.9837037037037037)
# Balanced Executability for blocksworld: (0.28044776143401734, 0.9837037037037037)
# Balanced Executability for blocksworld: (0.28044776143401734, 0.9837037037037037)
# Balanced Executability for blocksworld: (0.28044776143401734, 0.9837037037037037)
# Balanced Executability for blocksworld: (0.28044776143401734, 0.9837037037037037)
# Balanced Executability for blocksworld: (0.28044776143401734, 0.9837037037037037)
# Balanced Executability for blocksworld: (0.19686526926633768, 0.9986531986531986)
# Balanced Executability for blocksworld: (0.19686526926633768, 0.9986531986531986)
# Balanced Executability for blocksworld: (0.19686526926633768, 0.9986531986531986)
# Balanced Executability for blocksworld: (0.19686526926633768, 0.9986531986531986)
# Balanced Executability for blocksworld: (0.19686526926633768, 0.9986531986531986)
# Balanced Executability for blocksworld: (0.4147834429608808, 0.9854545454545455)
# Balanced Executability for blocksworld: (0.28044776143401734, 0.9837037037037037)
# Balanced Executability for blocksworld: (0.3002094816411195, 0.9878787878787879)
# Balanced Executability for blocksworld: (0.4671028675115175, 0.9799326599326599)
# Balanced Executability for blocksworld: (0.19686526926633768, 0.9986531986531986)
# Balanced Executability for blocksworld: (0.40513898181553243, 0.9854545454545455)
# Balanced Executability for blocksworld: (0.4147834429608808, 0.9854545454545455)
# Balanced Executability for blocksworld: (0.28044776143401734, 0.9837037037037037)
# Balanced Executability for blocksworld: (0.4390826220857631, 0.9854545454545455)
# Balanced Executability for blocksworld: (0.28044776143401734, 0.9837037037037037)
# Balanced Executability for blocksworld: (0.28044776143401734, 0.9837037037037037)
# Balanced Executability for blocksworld: (0.28044776143401734, 0.9837037037037037)
# Balanced Executability for blocksworld: (0.28044776143401734, 0.9837037037037037)
# Balanced Executability for blocksworld: (0.40513898181553243, 0.9854545454545455)
# Balanced Executability for blocksworld: (0.28044776143401734, 0.9837037037037037)
# Balanced Executability for blocksworld: (0.28044776143401734, 0.9837037037037037)
# Balanced Executability for blocksworld: (0.28044776143401734, 0.9837037037037037)
# Balanced Executability for blocksworld: (0.28044776143401734, 0.9837037037037037)
# Balanced Executability for blocksworld: (0.28044776143401734, 0.9837037037037037)
# Balanced Executability for blocksworld: (0.4154280381168697, 0.9819528619528619)
# Balanced Executability for blocksworld: (0.28044776143401734, 0.9837037037037037)
# Balanced Executability for blocksworld: (0.3743502810523842, 0.983030303030303)
# Balanced Executability for blocksworld: (0.28044776143401734, 0.9837037037037037)
# Balanced Executability for blocksworld: (0.4671028675115175, 0.9799326599326599)
# Balanced Executability for blocksworld: (0.39955124583067786, 0.9819528619528619)
# Balanced Executability for blocksworld: (0.19686526926633768, 0.9986531986531986)
# Balanced Executability for blocksworld: (0.19686526926633768, 0.9986531986531986)
# Balanced Executability for blocksworld: (0.19686526926633768, 0.9986531986531986)
# Balanced Executability for blocksworld: (0.19686526926633768, 0.9986531986531986)
# Balanced Executability for blocksworld: (0.4671028675115175, 0.9799326599326599)
# Balanced Executability for blocksworld: (0.3225023755864851, 0.9878787878787879)
# Balanced Executability for blocksworld: (0.43783288493660827, 0.9870707070707071)
# Balanced Executability for blocksworld: (0.4671028675115175, 0.9799326599326599)
# Balanced Executability for blocksworld: (0.40972934333723154, 0.9870707070707071)
# Balanced Executability for blocksworld: (0.28044776143401734, 0.9837037037037037)
# Balanced Executability for blocksworld: (0.28044776143401734, 0.9837037037037037)
# Balanced Executability for blocksworld: (0.28044776143401734, 0.9837037037037037)
# Balanced Executability for blocksworld: (0.28044776143401734, 0.9837037037037037)
# Balanced Executability for blocksworld: (0.4051073584261386, 0.9854545454545455)
# Balanced Executability for blocksworld: (0.4390826220857631, 0.9854545454545455)
# Balanced Executability for blocksworld: (0.41375391405604867, 0.9835690235690235)
# Balanced Executability for blocksworld: (0.43558767062401876, 0.9815488215488216)
# Balanced Executability for blocksworld: (0.28044776143401734, 0.9837037037037037)
# Balanced Executability for blocksworld: (0.40513898181553243, 0.9854545454545455)
# Balanced Executability for blocksworld: (0.28044776143401734, 0.9837037037037037)
# Balanced Executability for blocksworld: (0.28044776143401734, 0.9837037037037037)
# Balanced Executability for blocksworld: (0.43558767062401876, 0.9815488215488216)
# Balanced Executability for blocksworld: (0.28044776143401734, 0.9837037037037037)
# Balanced Executability for blocksworld: (0.28044776143401734, 0.9837037037037037)
# Balanced Executability for blocksworld: (0.40513898181553243, 0.9854545454545455)
# Balanced Executability for blocksworld: (0.33050171617643026, 0.9885521885521885)
# Balanced Executability for blocksworld: (0.40972934333723154, 0.9870707070707071)
# Balanced Executability for blocksworld: (0.40972934333723154, 0.9870707070707071)
# Balanced Executability for blocksworld: (0.4390826220857631, 0.9854545454545455)
# Balanced Executability for blocksworld: (0.4390826220857631, 0.9854545454545455)
# Balanced Executability for blocksworld: (0.4390826220857631, 0.9854545454545455)
# Balanced Executability for blocksworld: (0.4390826220857631, 0.9854545454545455)
# Balanced Executability for blocksworld: (0.39955124583067786, 0.9819528619528619)
# Balanced Executability for blocksworld: (0.4390826220857631, 0.9854545454545455)
# Balanced Executability for blocksworld: (0.4390826220857631, 0.9854545454545455)
# Balanced Executability for blocksworld: (0.4390826220857631, 0.9854545454545455)
# Balanced Executability for blocksworld: (0.4147834429608808, 0.9854545454545455)
# Balanced Executability for blocksworld: (0.4390826220857631, 0.9854545454545455)
# Balanced Executability for blocksworld: (0.40513898181553243, 0.9854545454545455)
# Balanced Executability for blocksworld: (0.4390826220857631, 0.9854545454545455)
# Balanced Executability for blocksworld: (0.41375391405604867, 0.9835690235690235)
# Balanced Executability for blocksworld: (0.39955124583067786, 0.9819528619528619)
# Balanced Executability for blocksworld: (0.4147834429608808, 0.9854545454545455)
# Balanced Executability for blocksworld: (0.40972934333723154, 0.9870707070707071)
# Balanced Executability for blocksworld: (0.4390826220857631, 0.9854545454545455)
# Balanced Executability for blocksworld: (0.40513898181553243, 0.9854545454545455)
# Balanced Executability for blocksworld: (0.4390826220857631, 0.9854545454545455)
# Balanced Executability for blocksworld: (0.38740779269111536, 0.9854545454545455)
# Balanced Executability for blocksworld: (0.4390826220857631, 0.9854545454545455)
# Balanced Executability for blocksworld: (0.39955124583067786, 0.9819528619528619)
# Balanced Executability for blocksworld: (0.43783288493660827, 0.9870707070707071)
# Balanced Executability for blocksworld: (0.4147834429608808, 0.9854545454545455)
# Balanced Executability for blocksworld: (0.4390826220857631, 0.9854545454545455)
# Balanced Executability for blocksworld: (0.4390826220857631, 0.9854545454545455)
# Balanced Executability for blocksworld: (0.4390826220857631, 0.9854545454545455)
# Balanced Executability for blocksworld: (0.43783288493660827, 0.9870707070707071)
# Balanced Executability for blocksworld: (0.4390826220857631, 0.9854545454545455)
# Balanced Executability for blocksworld: (0.4390826220857631, 0.9854545454545455)
# Balanced Executability for blocksworld: (0.4390826220857631, 0.9854545454545455)
# Balanced Executability for blocksworld: (0.4390826220857631, 0.9854545454545455)
# Balanced Executability for blocksworld: (0.4390826220857631, 0.9854545454545455)
# Balanced Executability for blocksworld: (0.40513898181553243, 0.9854545454545455)
# Balanced Executability for blocksworld: (0.4390826220857631, 0.9854545454545455)
# Balanced Executability for blocksworld: (0.4390826220857631, 0.9854545454545455)
# Balanced Executability for blocksworld: (0.4147834429608808, 0.9854545454545455)
# Balanced Executability for blocksworld: (0.4390826220857631, 0.9854545454545455)
# Balanced Executability for blocksworld: (0.4390826220857631, 0.9854545454545455)
# Balanced Executability for blocksworld: (0.4390826220857631, 0.9854545454545455)
# Balanced Executability for blocksworld: (0.4390826220857631, 0.9854545454545455)
# Balanced Executability for blocksworld: (0.4390826220857631, 0.9854545454545455)
# Balanced Executability for blocksworld: (0.4390826220857631, 0.9854545454545455)
# Balanced Executability for blocksworld: (0.4390826220857631, 0.9854545454545455)
# Balanced Executability for blocksworld: (0.4390826220857631, 0.9854545454545455)
# Balanced Executability for blocksworld: (0.4390826220857631, 0.9854545454545455)
# Balanced Executability for blocksworld: (0.4390826220857631, 0.9854545454545455)
# Balanced Executability for blocksworld: (0.4390826220857631, 0.9854545454545455)
# Balanced Executability for blocksworld: (0.4390826220857631, 0.9854545454545455)
# Balanced Executability for blocksworld: (0.4390826220857631, 0.9854545454545455)
# Balanced Executability for blocksworld: (0.4390826220857631, 0.9854545454545455)
# Balanced Executability for blocksworld: (0.4147834429608808, 0.9854545454545455)
# Balanced Executability for blocksworld: (0.4390826220857631, 0.9854545454545455)
# Balanced Executability for blocksworld: (0.4390826220857631, 0.9854545454545455)
# Balanced Executability for blocksworld: (0.43558767062401876, 0.9815488215488216)
# Balanced Executability for blocksworld: (0.4390826220857631, 0.9854545454545455)
# Testing domain: childsnack
# Balanced Executability for childsnack: (0.4803173192076253, 1.0)
# Balanced Executability for childsnack: (0.4692557376485948, 1.0)
# Balanced Executability for childsnack: (0.2856974138861894, 1.0)
# Balanced Executability for childsnack: (0.4803173192076253, 1.0)
# Balanced Executability for childsnack: (0.4399035790362321, 0.996734693877551)
# Balanced Executability for childsnack: (0.37959448101029736, 1.0)
# Balanced Executability for childsnack: (0.2856974138861894, 1.0)
# Balanced Executability for childsnack: (0.5808313946069048, 1.0)
# Balanced Executability for childsnack: (0.4803173192076253, 1.0)
# Balanced Executability for childsnack: (0.410747624446604, 1.0)
# Balanced Executability for childsnack: (0.4803173192076253, 1.0)
# Balanced Executability for childsnack: (0.4692557376485948, 1.0)
# Balanced Executability for childsnack: (0.410747624446604, 1.0)
# Balanced Executability for childsnack: (0.5808313946069048, 1.0)
# Balanced Executability for childsnack: (0.2856974138861894, 1.0)
# Balanced Executability for childsnack: (0.5742143863317333, 1.0)
# Balanced Executability for childsnack: (0.5437493803437682, 1.0)
# Balanced Executability for childsnack: (0.5035152116402116, 0.9975510204081632)
# Balanced Executability for childsnack: (0.5808313946069048, 1.0)
# Balanced Executability for childsnack: (0.37959448101029736, 1.0)
# Balanced Executability for childsnack: (0.31642279819575736, 1.0)
# Balanced Executability for childsnack: (0.43488808149522434, 1.0)
# Balanced Executability for childsnack: (0.5808313946069048, 1.0)
# Balanced Executability for childsnack: (0.5808313946069048, 1.0)
# Balanced Executability for childsnack: (0.5808313946069048, 1.0)
# Balanced Executability for childsnack: (0.5808313946069048, 1.0)
# Balanced Executability for childsnack: (0.5697698130478742, 1.0)
# Balanced Executability for childsnack: (0.5808313946069048, 1.0)
# Balanced Executability for childsnack: (0.4669582977491141, 0.9975510204081632)
# Balanced Executability for childsnack: (0.5808313946069048, 1.0)
# Balanced Executability for childsnack: (0.6820462459875726, 1.0)
# Balanced Executability for childsnack: (0.4260925152889439, 1.0)
# Balanced Executability for childsnack: (0.3628881133983175, 1.0)
# Balanced Executability for childsnack: (0.4803173192076253, 1.0)
# Balanced Executability for childsnack: (0.5742143863317333, 1.0)
# Balanced Executability for childsnack: (0.5742143863317333, 1.0)
# Balanced Executability for childsnack: (0.5808313946069048, 1.0)
# Balanced Executability for childsnack: (0.3999701276614542, 1.0)
# Balanced Executability for childsnack: (0.5371323720685965, 1.0)
# Balanced Executability for childsnack: (0.31642279819575736, 1.0)
# Balanced Executability for childsnack: (0.7140536867705235, 0.996734693877551)
# Balanced Executability for childsnack: (0.2951256306996103, 1.0)
# Balanced Executability for childsnack: (0.5808313946069048, 1.0)
# Balanced Executability for childsnack: (0.4500288048119681, 1.0)
# Balanced Executability for childsnack: (0.5808313946069048, 1.0)
# Balanced Executability for childsnack: (0.4500288048119681, 1.0)
# Balanced Executability for childsnack: (0.4399035790362321, 0.996734693877551)
# Balanced Executability for childsnack: (0.40658713593662577, 1.0)
# Balanced Executability for childsnack: (0.707436678495352, 0.9983673469387755)
# Balanced Executability for childsnack: (0.5808313946069048, 1.0)
# Balanced Executability for childsnack: (0.5808313946069048, 1.0)
# Balanced Executability for childsnack: (0.40658713593662577, 1.0)
# Balanced Executability for childsnack: (0.31642279819575736, 1.0)
# Balanced Executability for childsnack: (0.40658713593662577, 1.0)
# Balanced Executability for childsnack: (0.2951256306996103, 1.0)
# Balanced Executability for childsnack: (0.40658713593662577, 1.0)
# Balanced Executability for childsnack: (0.5808313946069048, 1.0)
# Balanced Executability for childsnack: (0.4327095235641154, 1.0)
# Balanced Executability for childsnack: (0.4087122991332175, 1.0)
# Balanced Executability for childsnack: (0.7253727753727753, 0.9983673469387755)
# Balanced Executability for childsnack: (0.7140916514513453, 0.9983673469387755)
# Balanced Executability for childsnack: (0.7253727753727753, 0.9983673469387755)
# Balanced Executability for childsnack: (0.6607959024158003, 0.9983673469387755)
# Balanced Executability for childsnack: (0.7173327541694888, 0.9983673469387755)
# Balanced Executability for childsnack: (0.678069488617958, 0.9975510204081632)
# Balanced Executability for childsnack: (0.7253727753727753, 0.9983673469387755)
# Balanced Executability for childsnack: (0.7253727753727753, 0.9983673469387755)
# Balanced Executability for childsnack: (0.7173327541694888, 0.9983673469387755)
# Balanced Executability for childsnack: (0.7140536867705235, 0.996734693877551)
# Balanced Executability for childsnack: (0.7253727753727753, 0.9983673469387755)
# Balanced Executability for childsnack: (0.7251532330103758, 0.9983673469387755)
# Balanced Executability for childsnack: (0.7253727753727753, 0.9983673469387755)
# Balanced Executability for childsnack: (0.7253727753727753, 0.9983673469387755)
# Balanced Executability for childsnack: (0.7253727753727753, 0.9983673469387755)
# Balanced Executability for childsnack: (0.7253727753727753, 0.9983673469387755)
# Balanced Executability for childsnack: (0.678069488617958, 0.9975510204081632)
# Balanced Executability for childsnack: (0.4669582977491141, 0.9975510204081632)
# Balanced Executability for childsnack: (0.7140536867705235, 0.996734693877551)
# Balanced Executability for childsnack: (0.6793659382945098, 0.9983673469387755)
# Balanced Executability for childsnack: (0.7140536867705235, 0.996734693877551)
# Balanced Executability for childsnack: (0.6793659382945098, 0.9983673469387755)
# Balanced Executability for childsnack: (0.7253727753727753, 0.9983673469387755)
# Balanced Executability for childsnack: (0.7253727753727753, 0.9983673469387755)
# Balanced Executability for childsnack: (0.7253727753727753, 0.9983673469387755)
# Balanced Executability for childsnack: (0.7253727753727753, 0.9983673469387755)
# Balanced Executability for childsnack: (0.7140916514513453, 0.9983673469387755)
# Balanced Executability for childsnack: (0.7253727753727753, 0.9983673469387755)
# Balanced Executability for childsnack: (0.7253727753727753, 0.9983673469387755)
# Balanced Executability for childsnack: (0.7253727753727753, 0.9983673469387755)
# Balanced Executability for childsnack: (0.7173327541694888, 0.9983673469387755)
# Balanced Executability for childsnack: (0.7253727753727753, 0.9983673469387755)
# Balanced Executability for childsnack: (0.7253727753727753, 0.9983673469387755)
# Balanced Executability for childsnack: (0.6104690859027594, 0.996734693877551)
# Balanced Executability for childsnack: (0.7140536867705235, 0.996734693877551)
# Balanced Executability for childsnack: (0.6793659382945098, 0.9983673469387755)
# Balanced Executability for childsnack: (0.7253727753727753, 0.9983673469387755)
# Balanced Executability for childsnack: (0.7140536867705235, 0.996734693877551)
# Balanced Executability for childsnack: (0.7253727753727753, 0.9983673469387755)
# Balanced Executability for childsnack: (0.6793659382945098, 0.9983673469387755)
# Balanced Executability for childsnack: (0.7253727753727753, 0.9983673469387755)
# Balanced Executability for childsnack: (0.7253727753727753, 0.9983673469387755)
# Balanced Executability for childsnack: (0.7173327541694888, 0.9983673469387755)
# Balanced Executability for childsnack: (0.7251532330103758, 0.9983673469387755)
# Balanced Executability for childsnack: (0.7253727753727753, 0.9983673469387755)
# Balanced Executability for childsnack: (0.681091018297651, 0.9983673469387755)
# Balanced Executability for childsnack: (0.7173327541694888, 0.9983673469387755)
# Balanced Executability for childsnack: (0.6820462459875726, 1.0)
# Balanced Executability for childsnack: (0.6939485660786682, 0.9983673469387755)
# Balanced Executability for childsnack: (0.7106684372883353, 0.9983673469387755)
# Balanced Executability for childsnack: (0.7253727753727753, 0.9983673469387755)
# Balanced Executability for childsnack: (0.7140536867705235, 0.996734693877551)
# Balanced Executability for childsnack: (0.6793659382945098, 0.9983673469387755)
# Balanced Executability for childsnack: (0.7106684372883353, 0.9983673469387755)
# Balanced Executability for childsnack: (0.7253727753727753, 0.9983673469387755)
# Balanced Executability for childsnack: (0.7143111938137447, 0.9983673469387755)
# Balanced Executability for childsnack: (0.7253727753727753, 0.9983673469387755)
# Balanced Executability for childsnack: (0.7253727753727753, 0.9983673469387755)
# Balanced Executability for childsnack: (0.7253727753727753, 0.9983673469387755)
# Balanced Executability for childsnack: (0.7143111938137447, 0.9983673469387755)
# Balanced Executability for childsnack: (0.6793659382945098, 0.9983673469387755)
# Balanced Executability for childsnack: (0.7253727753727753, 0.9983673469387755)
# Balanced Executability for childsnack: (0.6939485660786682, 0.9983673469387755)
# Balanced Executability for childsnack: (0.7253727753727753, 0.9983673469387755)
# Balanced Executability for childsnack: (0.7253727753727753, 0.9983673469387755)
# Balanced Executability for childsnack: (0.7253727753727753, 0.9983673469387755)
# Balanced Executability for childsnack: (0.7143111938137447, 0.9983673469387755)
# Balanced Executability for childsnack: (0.7253727753727753, 0.9983673469387755)
# Balanced Executability for childsnack: (0.6820462459875726, 1.0)
# Balanced Executability for childsnack: (0.7143111938137447, 0.9983673469387755)
# Balanced Executability for childsnack: (0.7253727753727753, 0.9983673469387755)
# Balanced Executability for childsnack: (0.2626046482806687, 1.0)
# Balanced Executability for childsnack: (0.7140536867705235, 0.996734693877551)
# Balanced Executability for childsnack: (0.7143111938137447, 0.9983673469387755)
# Balanced Executability for childsnack: (0.7253727753727753, 0.9983673469387755)
# Balanced Executability for childsnack: (0.6793659382945098, 0.9983673469387755)
# Balanced Executability for childsnack: (0.6793659382945098, 0.9983673469387755)
# Balanced Executability for childsnack: (0.7253727753727753, 0.9983673469387755)
# Balanced Executability for childsnack: (0.7253727753727753, 0.9983673469387755)
# Balanced Executability for childsnack: (0.7253727753727753, 0.9983673469387755)
# Balanced Executability for childsnack: (0.7253727753727753, 0.9983673469387755)
# Balanced Executability for childsnack: (0.6905233763779682, 0.9983673469387755)
# Balanced Executability for childsnack: (0.7238853304669631, 0.9983673469387755)
# Balanced Executability for childsnack: (0.7253727753727753, 0.9983673469387755)
# Testing domain: ferry
# Balanced Executability for ferry: (0.260590355143869, 1.0)
# Balanced Executability for ferry: (0.2527733889395089, 1.0)
# Balanced Executability for ferry: (0.260590355143869, 1.0)
# Balanced Executability for ferry: (0.20104675418870646, 1.0)
# Balanced Executability for ferry: (0.9166416321303616, 0.9741496839742454)
# Balanced Executability for ferry: (0.9166416321303616, 0.9741496839742454)
# Balanced Executability for ferry: (0.260590355143869, 1.0)
# Balanced Executability for ferry: (0.2527733889395089, 1.0)
# Balanced Executability for ferry: (0.260590355143869, 1.0)
# Balanced Executability for ferry: (0.20104675418870646, 1.0)
# Balanced Executability for ferry: (0.2527733889395089, 1.0)
# Balanced Executability for ferry: (0.2291522195980566, 1.0)
# Balanced Executability for ferry: (0.20104675418870646, 1.0)
# Balanced Executability for ferry: (0.2527733889395089, 1.0)
# Balanced Executability for ferry: (0.20104675418870646, 1.0)
# Balanced Executability for ferry: (0.9166416321303616, 0.9741496839742454)
# Balanced Executability for ferry: (0.260590355143869, 1.0)
# Balanced Executability for ferry: (0.260590355143869, 1.0)
# Balanced Executability for ferry: (0.260590355143869, 1.0)
# Balanced Executability for ferry: (0.20104675418870646, 1.0)
# Balanced Executability for ferry: (0.2527733889395089, 1.0)
# Balanced Executability for ferry: (0.260590355143869, 1.0)
# Balanced Executability for ferry: (0.260590355143869, 1.0)
# Balanced Executability for ferry: (0.2527733889395089, 1.0)
# Balanced Executability for ferry: (0.2527733889395089, 1.0)
# Balanced Executability for ferry: (0.260590355143869, 1.0)
# Balanced Executability for ferry: (0.20104675418870646, 1.0)
# Balanced Executability for ferry: (0.20104675418870646, 1.0)
# Balanced Executability for ferry: (0.260590355143869, 1.0)
# Balanced Executability for ferry: (0.2527733889395089, 1.0)
# Balanced Executability for ferry: (0.260590355143869, 1.0)
# Balanced Executability for ferry: (0.260590355143869, 1.0)
# Balanced Executability for ferry: (0.260590355143869, 1.0)
# Balanced Executability for ferry: (0.2527733889395089, 1.0)
# Balanced Executability for ferry: (0.2527733889395089, 1.0)
# Balanced Executability for ferry: (0.260590355143869, 1.0)
# Balanced Executability for ferry: (0.9166416321303616, 0.9741496839742454)
# Balanced Executability for ferry: (0.9852426183020898, 0.941143650442257)
# Balanced Executability for ferry: (0.260590355143869, 1.0)
# Balanced Executability for ferry: (0.9852426183020898, 0.941143650442257)
# Balanced Executability for ferry: (0.260590355143869, 1.0)
# Balanced Executability for ferry: (0.260590355143869, 1.0)
# Balanced Executability for ferry: (0.260590355143869, 1.0)
# Balanced Executability for ferry: (0.2527733889395089, 1.0)
# Balanced Executability for ferry: (0.260590355143869, 1.0)
# Balanced Executability for ferry: (0.9166416321303616, 0.9741496839742454)
# Balanced Executability for ferry: (0.260590355143869, 1.0)
# Balanced Executability for ferry: (0.260590355143869, 1.0)
# Balanced Executability for ferry: (0.260590355143869, 1.0)
# Balanced Executability for ferry: (0.260590355143869, 1.0)
# Balanced Executability for ferry: (0.9852426183020898, 0.941143650442257)
# Balanced Executability for ferry: (0.9166416321303616, 0.9741496839742454)
# Balanced Executability for ferry: (0.260590355143869, 1.0)
# Balanced Executability for ferry: (0.260590355143869, 1.0)
# Balanced Executability for ferry: (0.260590355143869, 1.0)
# Balanced Executability for ferry: (0.260590355143869, 1.0)
# Balanced Executability for ferry: (0.9852426183020898, 0.941143650442257)
# Balanced Executability for ferry: (0.260590355143869, 1.0)
# Balanced Executability for ferry: (0.9852426183020898, 0.941143650442257)
# Balanced Executability for ferry: (0.9852426183020898, 0.941143650442257)
# Balanced Executability for ferry: (0.9852426183020898, 0.941143650442257)
# Balanced Executability for ferry: (0.260590355143869, 1.0)
# Balanced Executability for ferry: (0.260590355143869, 1.0)
# Balanced Executability for ferry: (0.260590355143869, 1.0)
# Balanced Executability for ferry: (0.9852426183020898, 0.941143650442257)
# Balanced Executability for ferry: (0.9166416321303616, 0.9741496839742454)
# Balanced Executability for ferry: (0.260590355143869, 1.0)
# Balanced Executability for ferry: (0.9852426183020898, 0.941143650442257)
# Balanced Executability for ferry: (0.260590355143869, 1.0)
# Balanced Executability for ferry: (0.9852426183020898, 0.941143650442257)
# Balanced Executability for ferry: (0.9852426183020898, 0.941143650442257)
# Balanced Executability for ferry: (0.9852426183020898, 0.941143650442257)
# Balanced Executability for ferry: (0.260590355143869, 1.0)
# Balanced Executability for ferry: (0.260590355143869, 1.0)
# Balanced Executability for ferry: (0.9852426183020898, 0.941143650442257)
# Balanced Executability for ferry: (0.260590355143869, 1.0)
# Balanced Executability for ferry: (0.260590355143869, 1.0)
# Balanced Executability for ferry: (0.9852426183020898, 0.941143650442257)
# Balanced Executability for ferry: (0.9852426183020898, 0.941143650442257)
# Balanced Executability for ferry: (0.9852426183020898, 0.941143650442257)
# Balanced Executability for ferry: (0.9852426183020898, 0.941143650442257)
# Balanced Executability for ferry: (0.9166416321303616, 0.9741496839742454)
# Balanced Executability for ferry: (0.260590355143869, 1.0)
# Balanced Executability for ferry: (0.260590355143869, 1.0)
# Balanced Executability for ferry: (0.9852426183020898, 0.941143650442257)
# Balanced Executability for ferry: (0.260590355143869, 1.0)
# Balanced Executability for ferry: (0.260590355143869, 1.0)
# Balanced Executability for ferry: (0.2527733889395089, 1.0)
# Balanced Executability for ferry: (0.9852426183020898, 0.941143650442257)
# Balanced Executability for ferry: (0.9852426183020898, 0.941143650442257)
# Balanced Executability for ferry: (0.2527733889395089, 1.0)
# Balanced Executability for ferry: (0.260590355143869, 1.0)
# Balanced Executability for ferry: (0.260590355143869, 1.0)
# Balanced Executability for ferry: (0.260590355143869, 1.0)
# Balanced Executability for ferry: (0.2527733889395089, 1.0)
# Balanced Executability for ferry: (0.9852426183020898, 0.941143650442257)
# Balanced Executability for ferry: (0.9852426183020898, 0.941143650442257)
# Balanced Executability for ferry: (0.260590355143869, 1.0)
# Balanced Executability for ferry: (0.9852426183020898, 0.941143650442257)
# Balanced Executability for ferry: (0.260590355143869, 1.0)
# Balanced Executability for ferry: (0.260590355143869, 1.0)
# Balanced Executability for ferry: (0.260590355143869, 1.0)
# Balanced Executability for ferry: (0.9852426183020898, 0.941143650442257)
# Balanced Executability for ferry: (0.9852426183020898, 0.941143650442257)
# Balanced Executability for ferry: (0.9852426183020898, 0.941143650442257)
# Balanced Executability for ferry: (0.9852426183020898, 0.941143650442257)
# Balanced Executability for ferry: (0.260590355143869, 1.0)
# Balanced Executability for ferry: (0.9852426183020898, 0.941143650442257)
# Balanced Executability for ferry: (0.9852426183020898, 0.941143650442257)
# Balanced Executability for ferry: (0.260590355143869, 1.0)
# Balanced Executability for ferry: (0.260590355143869, 1.0)
# Balanced Executability for ferry: (0.9852426183020898, 0.941143650442257)
# Balanced Executability for ferry: (0.9852426183020898, 0.941143650442257)
# Balanced Executability for ferry: (0.260590355143869, 1.0)
# Balanced Executability for ferry: (0.9852426183020898, 0.941143650442257)
# Balanced Executability for ferry: (0.9852426183020898, 0.941143650442257)
# Balanced Executability for ferry: (0.2527733889395089, 1.0)
# Balanced Executability for ferry: (0.9852426183020898, 0.941143650442257)
# Balanced Executability for ferry: (0.9852426183020898, 0.941143650442257)
# Balanced Executability for ferry: (0.260590355143869, 1.0)
# Balanced Executability for ferry: (0.9852426183020898, 0.941143650442257)
# Balanced Executability for ferry: (0.260590355143869, 1.0)
# Balanced Executability for ferry: (0.9852426183020898, 0.941143650442257)
# Balanced Executability for ferry: (0.9852426183020898, 0.941143650442257)
# Balanced Executability for ferry: (0.9852426183020898, 0.941143650442257)
# Balanced Executability for ferry: (0.9852426183020898, 0.941143650442257)
# Balanced Executability for ferry: (0.260590355143869, 1.0)
# Balanced Executability for ferry: (0.260590355143869, 1.0)
# Balanced Executability for ferry: (0.260590355143869, 1.0)
# Balanced Executability for ferry: (0.260590355143869, 1.0)
# Balanced Executability for ferry: (0.260590355143869, 1.0)
# Balanced Executability for ferry: (0.260590355143869, 1.0)
# Balanced Executability for ferry: (0.260590355143869, 1.0)
# Balanced Executability for ferry: (0.260590355143869, 1.0)
# Balanced Executability for ferry: (0.9852426183020898, 0.941143650442257)
# Balanced Executability for ferry: (0.9852426183020898, 0.941143650442257)
# Balanced Executability for ferry: (0.9852426183020898, 0.941143650442257)
# Balanced Executability for ferry: (0.9852426183020898, 0.941143650442257)
# Balanced Executability for ferry: (0.9852426183020898, 0.941143650442257)
# Balanced Executability for ferry: (0.260590355143869, 1.0)
# Balanced Executability for ferry: (0.9852426183020898, 0.941143650442257)
# Balanced Executability for ferry: (0.260590355143869, 1.0)
# Testing domain: floortile
# Balanced Executability for floortile: (0.0989220695124389, 1.0)
# Balanced Executability for floortile: (0.039265026341674024, 1.0)
# Balanced Executability for floortile: (0.1250069570991256, 1.0)
# Balanced Executability for floortile: (0.09690918922116772, 1.0)
# Balanced Executability for floortile: (0.07567107425801789, 1.0)
# Balanced Executability for floortile: (0.1203037546635033, 1.0)
# Balanced Executability for floortile: (0.15605441990963415, 1.0)
# Balanced Executability for floortile: (0.1658575491731103, 1.0)
# Balanced Executability for floortile: (0.09685469866730403, 1.0)
# Balanced Executability for floortile: (0.13941854801633502, 1.0)
# Balanced Executability for floortile: (0.09442927082068242, 1.0)
# Balanced Executability for floortile: (0.1892156243969777, 1.0)
# Balanced Executability for floortile: (0.1456360423604921, 1.0)
# Balanced Executability for floortile: (0.1658575491731103, 1.0)
# Balanced Executability for floortile: (0.13941854801633502, 1.0)
# Balanced Executability for floortile: (0.13928603083466432, 1.0)
# Balanced Executability for floortile: (0.14519293922769938, 1.0)
# Balanced Executability for floortile: (0.13124048043497202, 1.0)
# Balanced Executability for floortile: (0.10201390390382342, 1.0)
# Balanced Executability for floortile: (0.09128903166508634, 1.0)
# Balanced Executability for floortile: (0.1530082957415858, 1.0)
# Balanced Executability for floortile: (0.14569062953651174, 1.0)
# Balanced Executability for floortile: (0.16219869394992956, 1.0)
# Balanced Executability for floortile: (0.12010494335043198, 1.0)
# Balanced Executability for floortile: (0.19384946001505923, 1.0)
# Balanced Executability for floortile: (0.17944729689836106, 1.0)
# Balanced Executability for floortile: (0.17944729689836106, 1.0)
# Balanced Executability for floortile: (0.11560365162907418, 1.0)
# Balanced Executability for floortile: (0.10143410315402121, 1.0)
# Balanced Executability for floortile: (0.13941854801633502, 1.0)
# Balanced Executability for floortile: (0.1257323440099658, 1.0)
# Balanced Executability for floortile: (0.11833995201596742, 1.0)
# Balanced Executability for floortile: (0.17296543329507472, 1.0)
# Balanced Executability for floortile: (0.1304103345892638, 1.0)
# Balanced Executability for floortile: (0.14508603370202863, 1.0)
# Balanced Executability for floortile: (0.18005803416870741, 1.0)
# Balanced Executability for floortile: (0.1658575491731103, 1.0)
# Balanced Executability for floortile: (0.13674336415277244, 1.0)
# Balanced Executability for floortile: (0.13941854801633502, 1.0)
# Balanced Executability for floortile: (0.17832341252751194, 1.0)
# Balanced Executability for floortile: (0.1300854350128506, 1.0)
# Balanced Executability for floortile: (0.1456360423604921, 1.0)
# Balanced Executability for floortile: (0.12046418604969648, 1.0)
# Balanced Executability for floortile: (0.16838753522373226, 1.0)
# Balanced Executability for floortile: (0.13373675201778149, 1.0)
# Balanced Executability for floortile: (0.13928603083466432, 1.0)
# Balanced Executability for floortile: (0.08150473963543754, 1.0)
# Balanced Executability for floortile: (0.08588323499429136, 1.0)
# Balanced Executability for floortile: (0.1495017424947477, 1.0)
# Balanced Executability for floortile: (0.16857270547483058, 1.0)
# Balanced Executability for floortile: (0.15922579008574292, 1.0)
# Balanced Executability for floortile: (0.1528757785599151, 1.0)
# Balanced Executability for floortile: (0.1630914902199985, 1.0)
# Balanced Executability for floortile: (0.15102002720438926, 1.0)
# Balanced Executability for floortile: (0.10000035442271735, 1.0)
# Balanced Executability for floortile: (0.1630914902199985, 1.0)
# Balanced Executability for floortile: (0.08351873289611818, 1.0)
# Balanced Executability for floortile: (0.17944729689836106, 1.0)
# Balanced Executability for floortile: (0.17944729689836106, 1.0)
# Balanced Executability for floortile: (0.1576862863208838, 1.0)
# Balanced Executability for floortile: (0.12305716014640321, 1.0)
# Balanced Executability for floortile: (0.1374302794791385, 1.0)
# Balanced Executability for floortile: (0.19614455024052846, 1.0)
# Balanced Executability for floortile: (0.10864643883696537, 1.0)
# Balanced Executability for floortile: (0.1378556806381936, 1.0)
# Balanced Executability for floortile: (0.18227436530628427, 1.0)
# Balanced Executability for floortile: (0.19346982701222787, 1.0)
# Balanced Executability for floortile: (0.14989191219187498, 1.0)
# Balanced Executability for floortile: (0.1343331414988838, 1.0)
# Balanced Executability for floortile: (0.4108146258886991, 0.9973224513172967)
# Balanced Executability for floortile: (0.18190480967041203, 1.0)
# Balanced Executability for floortile: (0.19156141505602092, 1.0)
# Balanced Executability for floortile: (0.14876689952506902, 1.0)
# Balanced Executability for floortile: (0.164132001186851, 1.0)
# Balanced Executability for floortile: (0.12906965173632343, 1.0)
# Balanced Executability for floortile: (0.18190480967041203, 1.0)
# Balanced Executability for floortile: (0.19614455024052846, 1.0)
# Balanced Executability for floortile: (0.19614455024052846, 1.0)
# Balanced Executability for floortile: (0.1592200182488379, 1.0)
# Balanced Executability for floortile: (0.1470700132082694, 1.0)
# Balanced Executability for floortile: (0.18190480967041203, 1.0)
# Balanced Executability for floortile: (0.12906965173632343, 1.0)
# Balanced Executability for floortile: (0.15582996814060784, 1.0)
# Balanced Executability for floortile: (0.17218108693941167, 1.0)
# Balanced Executability for floortile: (0.1432767515793349, 1.0)
# Balanced Executability for floortile: (0.1778752110496517, 1.0)
# Balanced Executability for floortile: (0.18227436530628427, 1.0)
# Balanced Executability for floortile: (0.1778752110496517, 1.0)
# Balanced Executability for floortile: (0.18227436530628427, 1.0)
# Balanced Executability for floortile: (0.1378556806381936, 1.0)
# Balanced Executability for floortile: (0.13729708941235824, 1.0)
# Balanced Executability for floortile: (0.1378556806381936, 1.0)
# Balanced Executability for floortile: (0.13104655000070428, 1.0)
# Balanced Executability for floortile: (0.1362153081272168, 1.0)
# Balanced Executability for floortile: (0.1811701123911579, 1.0)
# Balanced Executability for floortile: (0.13278231285752987, 1.0)
# Balanced Executability for floortile: (0.19346982701222787, 1.0)
# Balanced Executability for floortile: (0.13389350238875408, 1.0)
# Balanced Executability for floortile: (0.1417411046818758, 1.0)
# Balanced Executability for floortile: (0.21747768781349971, 1.0)
# Balanced Executability for floortile: (0.4591059516281507, 0.9964633447880871)
# Balanced Executability for floortile: (0.15982140673166978, 1.0)
# Balanced Executability for floortile: (0.13389350238875408, 1.0)
# Balanced Executability for floortile: (0.1748819733122859, 1.0)
# Balanced Executability for floortile: (0.1491989994160004, 1.0)
# Balanced Executability for floortile: (0.12005054801141227, 1.0)
# Balanced Executability for floortile: (0.2141093627266153, 1.0)
# Balanced Executability for floortile: (0.1778752110496517, 1.0)
# Balanced Executability for floortile: (0.12945844037025867, 1.0)
# Balanced Executability for floortile: (0.4591059516281507, 0.9964633447880871)
# Balanced Executability for floortile: (0.1378556806381936, 1.0)
# Balanced Executability for floortile: (0.14561590374758743, 1.0)
# Balanced Executability for floortile: (0.18844884526167782, 1.0)
# Balanced Executability for floortile: (0.16401989080821405, 1.0)
# Balanced Executability for floortile: (0.1470700132082694, 1.0)
# Balanced Executability for floortile: (0.1470700132082694, 1.0)
# Balanced Executability for floortile: (0.19346982701222787, 1.0)
# Balanced Executability for floortile: (0.15901100236346255, 1.0)
# Balanced Executability for floortile: (0.18216746645040482, 1.0)
# Balanced Executability for floortile: (0.1470700132082694, 1.0)
# Balanced Executability for floortile: (0.22022557046161564, 1.0)
# Balanced Executability for floortile: (0.16401989080821405, 1.0)
# Balanced Executability for floortile: (0.4535667744356799, 0.9964633447880871)
# Balanced Executability for floortile: (0.20306959634562327, 1.0)
# Balanced Executability for floortile: (0.18227436530628427, 1.0)
# Balanced Executability for floortile: (0.1453247983570933, 1.0)
# Balanced Executability for floortile: (0.4073831667179307, 0.9973224513172967)
# Balanced Executability for floortile: (0.2213711272226517, 1.0)
# Balanced Executability for floortile: (0.11026168370278416, 1.0)
# Balanced Executability for floortile: (0.20087870407228348, 1.0)
# Balanced Executability for floortile: (0.19346982701222787, 1.0)
# Balanced Executability for floortile: (0.17270910695690253, 1.0)
# Balanced Executability for floortile: (0.1811701123911579, 1.0)
# Balanced Executability for floortile: (0.2141093627266153, 1.0)
# Balanced Executability for floortile: (0.13104655000070428, 1.0)
# Balanced Executability for floortile: (0.22021120967715752, 1.0)
# Balanced Executability for floortile: (0.1821593971138303, 1.0)
# Balanced Executability for floortile: (0.4105564059099279, 0.9973224513172967)
# Balanced Executability for floortile: (0.44417324562357324, 0.9964633447880871)
# Balanced Executability for floortile: (0.1592803772617625, 1.0)
# Balanced Executability for floortile: (0.45040840334178134, 0.9964633447880871)
# Balanced Executability for floortile: (0.21733422589732007, 1.0)
# Balanced Executability for floortile: (0.1530082957415858, 1.0)
# Balanced Executability for floortile: (0.22513029042270538, 1.0)
# Balanced Executability for floortile: (0.22828731718403955, 1.0)
# Testing domain: miconic
# Balanced Executability for miconic: (0.4975918981533858, 0.9976767676767677)
# Balanced Executability for miconic: (0.17494753552947417, 1.0)
# Balanced Executability for miconic: (0.6519707274961363, 0.9944444444444445)
# Balanced Executability for miconic: (0.20557135144674804, 1.0)
# Balanced Executability for miconic: (0.6502631757885846, 0.9944444444444445)
# Balanced Executability for miconic: (0.5677200409693177, 0.9959595959595959)
# Balanced Executability for miconic: (0.20251844913881994, 1.0)
# Balanced Executability for miconic: (0.2003748878738149, 1.0)
# Balanced Executability for miconic: (0.23691615583689662, 0.9984006734006735)
# Balanced Executability for miconic: (0.4205509908939667, 0.9984343434343435)
# Balanced Executability for miconic: (0.19965765731251087, 1.0)
# Balanced Executability for miconic: (0.20557135144674804, 1.0)
# Balanced Executability for miconic: (0.19980564091186676, 0.9991919191919192)
# Balanced Executability for miconic: (0.28425706049898924, 0.9992424242424243)
# Balanced Executability for miconic: (0.19476285211320463, 1.0)
# Balanced Executability for miconic: (0.6171818258773732, 0.9921885521885522)
# Balanced Executability for miconic: (0.19476285211320463, 1.0)
# Balanced Executability for miconic: (0.20137512577594707, 1.0)
# Balanced Executability for miconic: (0.20200499876718223, 0.9991919191919192)
# Balanced Executability for miconic: (0.5678403361444913, 0.9952020202020202)
# Balanced Executability for miconic: (0.19915024108398222, 1.0)
# Balanced Executability for miconic: (0.631652312931873, 0.9944444444444445)
# Balanced Executability for miconic: (0.201081955349385, 1.0)
# Balanced Executability for miconic: (0.28425706049898924, 0.9992424242424243)
# Balanced Executability for miconic: (0.6490888136253169, 0.9944444444444445)
# Balanced Executability for miconic: (0.28425706049898924, 0.9992424242424243)
# Balanced Executability for miconic: (0.28425706049898924, 0.9992424242424243)
# Balanced Executability for miconic: (0.4252241016545573, 0.9992424242424243)
# Balanced Executability for miconic: (0.6171818258773732, 0.9921885521885522)
# Balanced Executability for miconic: (0.5496452288397479, 0.9952020202020202)
# Balanced Executability for miconic: (0.5496452288397479, 0.9952020202020202)
# Balanced Executability for miconic: (0.5677200409693177, 0.9959595959595959)
# Balanced Executability for miconic: (0.49356082915701244, 0.9976430976430977)
# Balanced Executability for miconic: (0.6519707274961363, 0.9944444444444445)
# Balanced Executability for miconic: (0.7250609816128881, 0.9944444444444445)
# Balanced Executability for miconic: (0.19938776043003795, 1.0)
# Balanced Executability for miconic: (0.8411162002664166, 0.9847727272727274)
# Balanced Executability for miconic: (0.27642650997426554, 1.0)
# Balanced Executability for miconic: (0.6512167029078396, 0.9952020202020202)
# Balanced Executability for miconic: (0.2854232351821798, 0.9992424242424243)
# Balanced Executability for miconic: (0.5678403361444913, 0.9952020202020202)
# Balanced Executability for miconic: (0.6171818258773732, 0.9921885521885522)
# Balanced Executability for miconic: (0.5755475652232988, 0.9952020202020202)
# Balanced Executability for miconic: (0.7250609816128881, 0.9944444444444445)
# Balanced Executability for miconic: (0.49462622871083445, 0.9976767676767677)
# Balanced Executability for miconic: (0.5755434762081152, 0.9952020202020202)
# Balanced Executability for miconic: (0.6502631757885846, 0.9944444444444445)
# Balanced Executability for miconic: (0.6501188756442845, 0.9944444444444445)
# Balanced Executability for miconic: (0.5755434762081152, 0.9952020202020202)
# Balanced Executability for miconic: (0.5769993521673977, 0.9944444444444445)
# Balanced Executability for miconic: (0.6519707274961363, 0.9944444444444445)
# Balanced Executability for miconic: (0.6409630668715972, 0.9935353535353536)
# Balanced Executability for miconic: (0.5678403361444913, 0.9952020202020202)
# Balanced Executability for miconic: (0.5757094949970983, 0.9952020202020202)
# Balanced Executability for miconic: (0.5757094949970983, 0.9952020202020202)
# Balanced Executability for miconic: (0.645470348983126, 0.9944444444444445)
# Balanced Executability for miconic: (0.2003748878738149, 1.0)
# Balanced Executability for miconic: (0.5797561249729051, 0.9952020202020202)
# Balanced Executability for miconic: (0.8513289919052206, 0.9851555963677175)
# Balanced Executability for miconic: (0.1949378278583885, 1.0)
# Balanced Executability for miconic: (0.5756769110935467, 0.9952020202020202)
# Balanced Executability for miconic: (0.2826296770648566, 0.9992424242424243)
# Balanced Executability for miconic: (0.7250609816128881, 0.9944444444444445)
# Balanced Executability for miconic: (0.6489258953690287, 0.9952020202020202)
# Balanced Executability for miconic: (0.7250609816128881, 0.9944444444444445)
# Balanced Executability for miconic: (0.8411162002664166, 0.9847727272727274)
# Balanced Executability for miconic: (0.5753166864444271, 0.9968181818181817)
# Balanced Executability for miconic: (0.5755434762081152, 0.9952020202020202)
# Balanced Executability for miconic: (0.7250609816128881, 0.9944444444444445)
# Balanced Executability for miconic: (0.7657164977567615, 0.9865656565656566)
# Balanced Executability for miconic: (0.7250609816128881, 0.9944444444444445)
# Balanced Executability for miconic: (0.7657164977567615, 0.9865656565656566)
# Balanced Executability for miconic: (0.1983076748621738, 1.0)
# Balanced Executability for miconic: (0.7250609816128881, 0.9944444444444445)
# Balanced Executability for miconic: (0.2854232351821798, 0.9992424242424243)
# Balanced Executability for miconic: (0.6519707274961363, 0.9944444444444445)
# Balanced Executability for miconic: (0.5797561249729051, 0.9952020202020202)
# Balanced Executability for miconic: (0.644838540704259, 0.9944444444444445)
# Balanced Executability for miconic: (0.6489258953690287, 0.9952020202020202)
# Balanced Executability for miconic: (0.6409630668715972, 0.9935353535353536)
# Balanced Executability for miconic: (0.49492925901386475, 0.9976767676767677)
# Balanced Executability for miconic: (0.5740515893161727, 0.9952020202020202)
# Balanced Executability for miconic: (0.2826296770648566, 0.9992424242424243)
# Balanced Executability for miconic: (0.6489258953690287, 0.9952020202020202)
# Balanced Executability for miconic: (0.715393151461572, 0.9903030303030302)
# Balanced Executability for miconic: (0.8513289919052206, 0.9851555963677175)
# Balanced Executability for miconic: (0.8411162002664166, 0.9847727272727274)
# Balanced Executability for miconic: (0.5740515893161727, 0.9952020202020202)
# Balanced Executability for miconic: (0.23691615583689662, 0.9984006734006735)
# Balanced Executability for miconic: (0.6519707274961363, 0.9944444444444445)
# Balanced Executability for miconic: (0.5730064667530235, 0.9952020202020202)
# ...
# Balanced Executability for spanner: (0.8903378717192332, 1.0)
# Balanced Executability for spanner: (0.622390723765476, 1.0)
# Balanced Executability for spanner: (0.7999153079424065, 1.0)
# Balanced Executability for spanner: (0.7999153079424065, 1.0)
# Balanced Executability for spanner: (0.9095774362231731, 1.0)
# Balanced Executability for spanner: (0.8903378717192332, 1.0)
# Balanced Executability for spanner: (0.8903378717192332, 1.0)
# Balanced Executability for spanner: (0.8903378717192332, 1.0)
# Balanced Executability for spanner: (0.8903378717192332, 1.0)
# Balanced Executability for spanner: (0.8903378717192332, 1.0)
# Balanced Executability for spanner: (0.8903378717192332, 1.0)
# Balanced Executability for spanner: (0.8903378717192332, 1.0)
# Balanced Executability for spanner: (0.8903378717192332, 1.0)
# Balanced Executability for spanner: (0.8903378717192332, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (0.7999153079424065, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (0.9095774362231731, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (0.9095774362231731, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (0.8903378717192332, 1.0)
# Balanced Executability for spanner: (0.8903378717192332, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (0.7999153079424065, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (0.9095774362231731, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (0.7999153079424065, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (0.9095774362231731, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (0.7999153079424065, 1.0)
# Balanced Executability for spanner: (0.9095774362231731, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (0.9095774362231731, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (0.8903378717192332, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (0.7999153079424065, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (0.9095774362231731, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (0.9095774362231731, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (0.7999153079424065, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Balanced Executability for spanner: (1.0, 1.0)
# Testing domain: transport
# Balanced Executability for transport: (0.1926296101959865, 1.0)
# Balanced Executability for transport: (0.7924964848681061, 0.9899054032387365)
# Balanced Executability for transport: (0.1926296101959865, 1.0)
# Balanced Executability for transport: (0.2874800879162857, 1.0)
# Balanced Executability for transport: (0.7610289212714796, 0.9908032708032708)
# Balanced Executability for transport: (0.1926296101959865, 1.0)
# Balanced Executability for transport: (0.1926296101959865, 1.0)
# Balanced Executability for transport: (0.44475622438133355, 0.9916690716690716)
# Balanced Executability for transport: (0.7929520743549477, 0.9899054032387365)
# Balanced Executability for transport: (0.1926296101959865, 1.0)
# Balanced Executability for transport: (0.2874800879162857, 1.0)
# Balanced Executability for transport: (0.44475622438133355, 0.9916690716690716)
# Balanced Executability for transport: (0.43430983622277075, 0.9991919191919192)
# Balanced Executability for transport: (0.7929520743549477, 0.9899054032387365)
# Balanced Executability for transport: (0.19307155636011716, 1.0)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.43430983622277075, 0.9991919191919192)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.16321377466857384, 1.0)
# Balanced Executability for transport: (0.5956060297589328, 0.9975757575757576)
# Balanced Executability for transport: (0.2874800879162857, 1.0)
# Balanced Executability for transport: (0.7929520743549477, 0.9899054032387365)
# Balanced Executability for transport: (0.6177964174708342, 0.9975757575757576)
# Balanced Executability for transport: (0.37270889693509046, 0.9975757575757576)
# Balanced Executability for transport: (0.19307155636011716, 1.0)
# Balanced Executability for transport: (0.7929520743549477, 0.9899054032387365)
# Balanced Executability for transport: (0.19307155636011716, 1.0)
# Balanced Executability for transport: (0.6141288951909579, 0.9975757575757576)
# Balanced Executability for transport: (0.7924964848681061, 0.9899054032387365)
# Balanced Executability for transport: (0.16321377466857384, 1.0)
# Balanced Executability for transport: (0.33900164528645016, 1.0)
# Balanced Executability for transport: (0.37270889693509046, 0.9975757575757576)
# Balanced Executability for transport: (0.19307155636011716, 1.0)
# Balanced Executability for transport: (0.7929520743549477, 0.9899054032387365)
# Balanced Executability for transport: (0.19307155636011716, 1.0)
# Balanced Executability for transport: (0.33900164528645016, 1.0)
# Balanced Executability for transport: (0.19307155636011716, 1.0)
# Balanced Executability for transport: (0.19307155636011716, 1.0)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.33900164528645016, 1.0)
# Balanced Executability for transport: (0.1926296101959865, 1.0)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.37270889693509046, 0.9975757575757576)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.19307155636011716, 1.0)
# Balanced Executability for transport: (0.43430983622277075, 0.9991919191919192)
# Balanced Executability for transport: (0.19307155636011716, 1.0)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.19307155636011716, 1.0)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.19307155636011716, 1.0)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.7929520743549477, 0.9899054032387365)
# Balanced Executability for transport: (0.7848958045555127, 0.9908032708032708)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.37270889693509046, 0.9975757575757576)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.7929520743549477, 0.9899054032387365)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.7929520743549477, 0.9899054032387365)
# Balanced Executability for transport: (0.19307155636011716, 1.0)
# Balanced Executability for transport: (0.19307155636011716, 1.0)
# Balanced Executability for transport: (0.19307155636011716, 1.0)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.19307155636011716, 1.0)
# Balanced Executability for transport: (0.1926296101959865, 1.0)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.1926296101959865, 1.0)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.16321377466857384, 1.0)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.19307155636011716, 1.0)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.44475622438133355, 0.9916690716690716)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.37270889693509046, 0.9975757575757576)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.1926296101959865, 1.0)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.19307155636011716, 1.0)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)
# Balanced Executability for transport: (0.8021610588161701, 0.9899054032387365)

# %%
# with open("../../data/plain_traces/plain_traces.txt", "r") as f:
#     with open("res.csv", "w") as out:
#         lines = f.readlines()
#         for line in lines:
#             try:
#                 details = line.split("&&")
#                 name = f"{details[0]}-{details[2]}-{details[3]}"
            
#                 plan = details[-1]
#                 trace = read_plan(plan)
           

#                 domain_name = details[0]
            
#                 exe_l, exe_gt = test_cross_exe(domain_name, trace, trace)
#             except Exception as e:
#                 print(f"Error processing task {name}: {e}")
#                 exe_l, exe_gt = 0, 0
#             print(f"Executability for {name}: {exe_l}, {exe_gt}")
#             out.write(f"{name},{exe_l}, {exe_gt}\n")
#             out.flush()

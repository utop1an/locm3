# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
from extract import LOCM2
from utils import read_plan, read_json_file
from evaluator import ExecutabilityEvaluator
from collections import defaultdict
import json

# %%
def test_cross_exe(domain_name, train_traces , prefix_traces, gt_traces=[]):
    debug = {}
    try:
        polocm2 = LOCM2(state_param=True, viz=False, debug=debug)
        model = polocm2.extract_model(train_traces)
        learned_domain = model.to_pddl_domain(domain_name)
        gt_filename = os.path.join('../../data', 'goose-benchmarks', 'tasks', domain_name, 'domain.pddl')
        
        evaluator = ExecutabilityEvaluator(learned_domain,gt_filename, debug=False)

        exe = evaluator.get_cross_executabilities(prefix_traces, gt_traces)
        return exe
    except Exception as e:
        print(f"Error processing domain {domain_name}: {e}")
        return 0,0
    
def test_cross_exe_with_invariants(domain_name, train_traces , prefix_traces, gt_traces=[]):
    debug = {}
    try:
        polocm2 = LOCM2(state_param=True, viz=False, debug=debug)
        model = polocm2.extract_model(train_traces)
        learned_domain = model.to_pddl_domain(domain_name)
        gt_filename = os.path.join('../../data', 'goose-benchmarks', 'tasks', domain_name, 'domain.pddl')
        
        evaluator = ExecutabilityEvaluator(learned_domain,gt_filename,invariant_check=True, debug=False)

        exe = evaluator.get_cross_executabilities(prefix_traces, gt_traces)
        return exe
    except Exception as e:
        print(f"Error processing domain {domain_name}: {e}")
        return 0,0
    
def test_balanced_exe(domain_name, train_traces, test_traces, test_invalid_traces):
    debug = {}
    try:
        polocm2 = LOCM2(state_param=True, viz=False, debug=debug)
        model = polocm2.extract_model(train_traces)
        learned_domain = model.to_pddl_domain(domain_name)
        gt_filename = os.path.join('../../data', 'goose-benchmarks', 'tasks', domain_name, 'domain.pddl')
        
        evaluator = ExecutabilityEvaluator(learned_domain, gt_filename, debug=False)
        exe = evaluator.get_balanced_executability(test_traces, test_invalid_traces)

        return exe
    except Exception as e:
        print(f"Error processing domain {domain_name}: {e}")
        return 0,0

# %%
plain_traces = defaultdict(list)
with open("../../data/plain_traces/plain_traces.txt", "r") as f:
    lines = f.readlines()
    for line in lines:
        details = line.split("&&")

        domain_name = details[0]
        plan = details[-1]

        plain_traces[domain_name].append(read_plan(plan))

# %%
train_traces = defaultdict(list)
data = read_json_file("../../data/training_data/traces_plan_r1.json")
for learning_obj in data:
    domain_name = learning_obj["domain"]
    train_traces[domain_name].append(learning_obj)

# %%
valid_traces = defaultdict(list)
invalid_traces = defaultdict(list)

with open("../../data/plain_traces/random_walks.txt", "r") as f:
    lines = f.readlines()
    for line in lines:
        details = line.split("&&")
        domain_name = details[0]
        is_valid = details[1] == "rand"
        plan = details[-1]
        if is_valid:
            valid_traces[domain_name].append(read_plan(plan))
        else:
            invalid_traces[domain_name].append(read_plan(plan))

# %%
# with open("./cross_exe_results.csv", "w") as f:
#     f.write("ID, Domain, len, objs, l_exe, gt_exe\n")
#     for domain, items in train_traces.items():
#         print(f"Testing domain: {domain}")
#         for item in items:
#             traces = item["traces"]

#             try:
#                 coress_exe = test_cross_exe(domain, traces, plain_traces[domain], plain_traces[domain])
#             except Exception as e:
#                 print(f"Error in balanced executability for domain {domain}: {e}")
#                 coress_exe = 0,0

#         # Test balanced executability
#             f.write(f"{item['id']}, {domain}, {item['total_length']}, {item['number_of_objects']}, {coress_exe[0]}, {coress_exe[1]}\n")
#             f.flush()
#             print(f"Cross Executability for {domain}: {coress_exe}")

# %%
# with open("./balanced_exe_results.csv", "w") as f:
#     f.write("ID, Domain, len, objs, valid_exe, invalid_exe\n")
#     for domain, items in train_traces.items():
#         print(f"Testing domain: {domain}")
#         for item in items:
#             traces = item["traces"]

#             try:
#                 balanced_exe = test_balanced_exe(domain, traces, valid_traces[domain], invalid_traces[domain])
#             except Exception as e:
#                 print(f"Error in balanced executability for domain {domain}: {e}")
#                 balanced_exe = 0,0

#         # Test balanced executability
#             f.write(f"{item['id']}, {domain}, {item['total_length']}, {item['number_of_objects']}, {balanced_exe[0]}, {balanced_exe[1]}\n")
#             f.flush()
#             print(f"Balanced Executability for {domain}: {balanced_exe}")

# %%
with open("./cross_exe_w_inv_results.csv", "w") as f:
    f.write("ID, Domain, len, objs, l_exe, gt_exe\n")
    for domain, items in train_traces.items():
        print(f"Testing domain: {domain}")
        for item in items:
            traces = item["traces"]

            try:
                coress_exe = test_cross_exe_with_invariants(domain, traces, plain_traces[domain], plain_traces[domain])
            except Exception as e:
                print(f"Error in balanced executability for domain {domain}: {e}")
                coress_exe = 0,0

        # Test balanced executability
            f.write(f"{item['id']}, {domain}, {item['total_length']}, {item['number_of_objects']}, {coress_exe[0]}, {coress_exe[1]}\n")
            f.flush()
            print(f"Cross Executability for {domain}: {coress_exe}")
# Out:
# Testing domain: blocksworld
# Cross Executability for blocksworld: (0.49481446543722457, 0.030303030303030304)
# Cross Executability for blocksworld: (0.54726748531232, 0.06060606060606061)
# Cross Executability for blocksworld: (0.5893494360618644, 0.9907407407407407)
# Cross Executability for blocksworld: (0.3736530849672458, 0.8501683501683501)
# Cross Executability for blocksworld: (0.5789783669363135, 0.679159318048207)
# Cross Executability for blocksworld: (0.5789783669363135, 0.6936160547271658)
# Cross Executability for blocksworld: (0.5051855345627754, 0.9696969696969697)
# Cross Executability for blocksworld: (0.5893494360618644, 0.9941077441077442)
# Cross Executability for blocksworld: (0.5893494360618644, 0.9941077441077442)
# Cross Executability for blocksworld: (0.3736530849672458, 0.8209876543209876)
# Cross Executability for blocksworld: (0.5789783669363135, 0.6888260916038694)
# Cross Executability for blocksworld: (0.8188258265147725, 0.9004797294557976)
# Cross Executability for blocksworld: (1.0, 0.9852498651741075)
# Cross Executability for blocksworld: (1.0, 0.5948653198653199)
# Cross Executability for blocksworld: (0.5789783669363135, 0.6840027256693924)
# Cross Executability for blocksworld: (0.3736530849672458, 0.8636363636363636)
# Cross Executability for blocksworld: (1.0, 0.5957190957190956)
# Cross Executability for blocksworld: (1.0, 0.5952861952861953)
# Cross Executability for blocksworld: (1.0, 0.5949401421623643)
# Cross Executability for blocksworld: (1.0, 0.9279628293517183)
# Cross Executability for blocksworld: (0.3736530849672458, 0.8372615039281707)
# Cross Executability for blocksworld: (1.0, 0.5953449842338732)
# Cross Executability for blocksworld: (1.0, 0.5949074074074074)
# Cross Executability for blocksworld: (1.0, 0.5955854844743733)
# Cross Executability for blocksworld: (0.3736530849672458, 0.8490460157126825)
# Cross Executability for blocksworld: (1.0, 0.5957190957190956)
# Cross Executability for blocksworld: (1.0, 0.5949775533108866)
# Cross Executability for blocksworld: (1.0, 0.5959595959595959)
# Cross Executability for blocksworld: (0.3736530849672458, 0.851290684624018)
# Testing domain: childsnack
# Cross Executability for childsnack: (0.6024334084283064, 0.0)
# Cross Executability for childsnack: (0.8098048635038432, 0.8571428571428571)
# Cross Executability for childsnack: (0.7200781503077421, 1.0)
# Cross Executability for childsnack: (0.3633523034033238, 0.8163265306122449)
# Cross Executability for childsnack: (0.6610793307221878, 0.8367346938775511)
# Cross Executability for childsnack: (0.7827155176644973, 0.9265306122448979)
# Cross Executability for childsnack: (0.5709157905586477, 1.0)
# Cross Executability for childsnack: (0.7662551167653209, 0.01020408163265306)
# Cross Executability for childsnack: (0.7200781503077421, 1.0)
# Cross Executability for childsnack: (0.3633523034033238, 0.8163265306122449)
# Cross Executability for childsnack: (0.862882100892305, 0.9988662131519275)
# Cross Executability for childsnack: (0.862882100892305, 1.0)
# Cross Executability for childsnack: (1.0, 1.0)
# Cross Executability for childsnack: (1.0, 1.0)
# Cross Executability for childsnack: (1.0, 1.0)
# Cross Executability for childsnack: (0.3633523034033238, 0.8163265306122449)
# Cross Executability for childsnack: (1.0, 1.0)
# Cross Executability for childsnack: (1.0, 1.0)
# Cross Executability for childsnack: (1.0, 1.0)
# Cross Executability for childsnack: (1.0, 1.0)
# Cross Executability for childsnack: (0.3633523034033238, 0.8163265306122449)
# Cross Executability for childsnack: (1.0, 1.0)
# Cross Executability for childsnack: (1.0, 1.0)
# Cross Executability for childsnack: (1.0, 1.0)
# Cross Executability for childsnack: (0.3633523034033238, 0.8163265306122449)
# Cross Executability for childsnack: (1.0, 1.0)
# Cross Executability for childsnack: (1.0, 1.0)
# Cross Executability for childsnack: (1.0, 1.0)
# Cross Executability for childsnack: (0.3633523034033238, 0.8163265306122449)
# Testing domain: ferry
# Cross Executability for ferry: (0.9578520899773342, 1.0)
# Cross Executability for ferry: (0.9792081487395772, 1.0)
# Cross Executability for ferry: (0.9578520899773342, 1.0)
# Cross Executability for ferry: (0.510801605107704, 0.0)
# Cross Executability for ferry: (0.978643941237757, 1.0)
# Cross Executability for ferry: (0.9578520899773342, 1.0)
# Cross Executability for ferry: (0.9792081487395772, 1.0)
# Cross Executability for ferry: (0.9792081487395772, 1.0)
# Cross Executability for ferry: (0.9578520899773342, 1.0)
# Cross Executability for ferry: (0.510801605107704, 0.0)
# Cross Executability for ferry: (0.978643941237757, 1.0)
# Cross Executability for ferry: (0.9792081487395772, 1.0)
# Cross Executability for ferry: (1.0, 1.0)
# Cross Executability for ferry: (0.9792081487395772, 1.0)
# Cross Executability for ferry: (1.0, 1.0)
# Cross Executability for ferry: (0.510801605107704, 0.0)
# Cross Executability for ferry: (1.0, 1.0)
# Cross Executability for ferry: (1.0, 1.0)
# Cross Executability for ferry: (0.9792081487395772, 1.0)
# Cross Executability for ferry: (1.0, 1.0)
# Cross Executability for ferry: (0.510801605107704, 0.0)
# Cross Executability for ferry: (1.0, 1.0)
# Cross Executability for ferry: (1.0, 1.0)
# Cross Executability for ferry: (1.0, 1.0)
# Cross Executability for ferry: (0.510801605107704, 0.0)
# Cross Executability for ferry: (1.0, 1.0)
# Cross Executability for ferry: (1.0, 1.0)
# Cross Executability for ferry: (1.0, 1.0)
# Cross Executability for ferry: (0.510801605107704, 0.0)
# Testing domain: floortile
# Cross Executability for floortile: (0.7498435621351305, 0.0429553264604811)
# Cross Executability for floortile: (0.779930280692354, 0.7359570174003164)
# Cross Executability for floortile: (0.2949216403227198, 0.8179512354770087)
# Cross Executability for floortile: (0.779930280692354, 0.7105255081149563)
# Cross Executability for floortile: (0.9182692688923887, 0.7577662982302158)
# Cross Executability for floortile: (0.7907720230119129, 0.7674476726023117)
# Cross Executability for floortile: (0.90553737579592, 0.7591066132624383)
# Cross Executability for floortile: (0.9182692688923887, 0.773563353609474)
# Cross Executability for floortile: (0.7880030291749968, 0.709238699444885)
# Cross Executability for floortile: (0.7880030291749968, 0.7174525442705874)
# Cross Executability for floortile: (0.8264369542377002, 0.711740979112631)
# Cross Executability for floortile: (0.9235730235381152, 0.8781659750097146)
# Cross Executability for floortile: (0.933296354852618, 0.7844416075941143)
# Cross Executability for floortile: (0.8206739067276809, 0.7775494504091544)
# Cross Executability for floortile: (0.8958233373816333, 0.7566791551327634)
# Cross Executability for floortile: (0.7880030291749968, 0.7026439536717557)
# Cross Executability for floortile: (0.9030393810388221, 0.8106909403286667)
# Cross Executability for floortile: (0.9108504233418626, 0.791932439269519)
# Cross Executability for floortile: (0.933296354852618, 0.7912818499969272)
# Cross Executability for floortile: (0.8208104855217053, 0.7454663173335064)
# Cross Executability for floortile: (0.7880030291749968, 0.6972998538779104)
# Cross Executability for floortile: (0.9108504233418626, 0.7738184967847553)
# Cross Executability for floortile: (0.9108504233418626, 0.7828221626468499)
# Cross Executability for floortile: (0.9079836555625677, 0.9268060988042794)
# Cross Executability for floortile: (0.7880030291749968, 0.7084336190475389)
# Cross Executability for floortile: (0.9643730163965127, 0.9045838155735983)
# Cross Executability for floortile: (0.9189231718245053, 0.8480222016867149)
# Cross Executability for floortile: (0.9503589901641174, 0.8336736191280858)
# Cross Executability for floortile: (0.7880030291749968, 0.6916596438394521)
# Testing domain: miconic
# Cross Executability for miconic: (0.5810149667677484, 0.9308267863823421)
# Cross Executability for miconic: (0.9103342060964791, 1.0)
# Cross Executability for miconic: (0.5754679717763503, 0.9378787878787879)
# Cross Executability for miconic: (0.6767979274387029, 0.7798059964726631)
# Cross Executability for miconic: (0.9150928598387126, 1.0)
# Cross Executability for miconic: (0.8510302922018324, 1.0)
# Cross Executability for miconic: (0.8989926190396083, 1.0)
# Cross Executability for miconic: (0.9973255130676419, 1.0)
# Cross Executability for miconic: (0.8510302922018324, 1.0)
# Cross Executability for miconic: (0.6767979274387029, 0.7826599326599326)
# Cross Executability for miconic: (0.9150928598387126, 1.0)
# Cross Executability for miconic: (0.8510302922018324, 1.0)
# Cross Executability for miconic: (0.9973255130676419, 1.0)
# Cross Executability for miconic: (0.9973255130676419, 1.0)
# Cross Executability for miconic: (0.9964962018935033, 1.0)
# Cross Executability for miconic: (0.6767979274387029, 0.7858666025332692)
# Cross Executability for miconic: (0.9150928598387126, 1.0)
# Cross Executability for miconic: (0.9973255130676419, 1.0)
# Cross Executability for miconic: (0.9992229992229992, 1.0)
# Cross Executability for miconic: (0.9964962018935033, 1.0)
# Cross Executability for miconic: (0.6767979274387029, 0.7799422799422799)
# Cross Executability for miconic: (0.9973255130676419, 1.0)
# Cross Executability for miconic: (0.9992229992229992, 1.0)
# Cross Executability for miconic: (0.9964962018935033, 1.0)
# Cross Executability for miconic: (0.6767979274387029, 0.7779461279461279)
# Cross Executability for miconic: (0.9973255130676419, 1.0)
# Cross Executability for miconic: (0.9992229992229992, 1.0)
# Cross Executability for miconic: (0.9964962018935033, 1.0)
# Cross Executability for miconic: (0.6767979274387029, 0.784664101330768)
# Testing domain: rovers
# Cross Executability for rovers: (0.2313214018212552, 0.12121212121212122)
# Cross Executability for rovers: (0.2833351898920558, 0.6868686868686869)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Cross Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Cross Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Cross Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Cross Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Cross Executability for rovers: (0, 0)
# Cross Executability for rovers: (0.3196584665035172, 0.12121212121212122)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Cross Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Cross Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Cross Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Cross Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Cross Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Cross Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Cross Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Cross Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Cross Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Cross Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Cross Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Cross Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Cross Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Cross Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Cross Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Cross Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Cross Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Cross Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Cross Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Cross Executability for rovers: (0, 0)
# Error processing domain rovers: LOCMv1 cannot handle duplicate objects in the same action.
# Cross Executability for rovers: (0, 0)
# Testing domain: satellite
# Cross Executability for satellite: (0.5125100501651072, 0.0)
# Cross Executability for satellite: (0.5425411908583002, 1.0)
# Cross Executability for satellite: (0.5575567612048966, 0.38554873186761)
# Cross Executability for satellite: (0.4719595148243713, 0.09090909090909091)
# Cross Executability for satellite: (0.5026636299863384, 0.9292929292929293)
# Cross Executability for satellite: (0.7674391202066692, 0.7272727272727273)
# Cross Executability for satellite: (0.8173606661540413, 0.9009543103562535)
# Cross Executability for satellite: (0.030031140693192977, 0.7575757575757576)
# Cross Executability for satellite: (0.6811068549626126, 0.8686868686868687)
# Cross Executability for satellite: (0.4719595148243713, 0.09090909090909091)
# Cross Executability for satellite: (0.6992012929661032, 0.13008583481808117)
# Cross Executability for satellite: (0.7033159459072449, 0.8459275292608626)
# Cross Executability for satellite: (0.9616512676315028, 0.494949494949495)
# Cross Executability for satellite: (0.9616512676315028, 0.494949494949495)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 9
#       6 traces = item["traces"]
#       8 try:
# ----> 9     coress_exe = test_cross_exe_with_invariants(domain, traces, plain_traces[domain], plain_traces[domain])
#      10 except Exception as e:
#      11     print(f"Error in balanced executability for domain {domain}: {e}")
#
# Cell In[2], line 27, in test_cross_exe_with_invariants(domain_name, train_traces, prefix_traces, gt_traces)
#      23     gt_filename = os.path.join('../../data', 'goose-benchmarks', 'tasks', domain_name, 'domain.pddl')
#      25     evaluator = ExecutabilityEvaluator(learned_domain,gt_filename,invariant_check=True, debug=False)
# ---> 27     exe = evaluator.get_cross_executabilities(prefix_traces, gt_traces)
#      28     return exe
#      29 except Exception as e:
#
# File ~/anu/codes/locm3/src/evaluator/executability_evaluator.py:165, in ExecutabilityEvaluator.get_cross_executabilities(self, prefix_seqs, gt_seqs, debug)
#     162     return sum(l_res)/len(l_res), sum(gt_res)/len(gt_res)
#     164 if prefix_seqs and gt_seqs:
# --> 165     l_items = self.generate_action_seqs('l', prefix_seqs)
#     167     l_res = []
#     168     gt_res = []
#
# File ~/anu/codes/locm3/src/evaluator/executability_evaluator.py:255, in ExecutabilityEvaluator.generate_action_seqs(self, domain_type, prefix_seqs, limits)
#     251         true_effs = true_effs.union(adds)
#     252         true_effs.difference_update(dels)
# --> 255     new_action_sequences = self.generate_action_seq(domain_type, type_objs, true_effs, visited, len(prefix_seq))
#     256     res.append((new_action_sequences, true_effs, visited, i))
#     257 return res
#
# File ~/anu/codes/locm3/src/evaluator/executability_evaluator.py:296, in ExecutabilityEvaluator.generate_action_seq(self, domain_type, type_objs, init_effs, init_visited, length, debug)
#     294 visited = init_visited.copy()
#     295 for i in range(length):
# --> 296     candiates = get_applicable_actions(true_effs, visited)
#     297     if (len(candiates) == 0):
#     298         break
#
# File ~/anu/codes/locm3/src/evaluator/executability_evaluator.py:277, in ExecutabilityEvaluator.generate_action_seq.<locals>.get_applicable_actions(_effs, _visited)
#     275 preconditions = set(action.precondition)
#     276 invalid = preconditions.difference(_effs)
# --> 277 invalid = invalid.intersection(_visited)
#     278 if (len(invalid)==0):
#     279     if self.invariant_check:
#
# KeyboardInterrupt:

# %%
# with open("../../data/plain_traces/plain_traces.txt", "r") as f:
#     with open("res.csv", "w") as out:
#         lines = f.readlines()
#         for line in lines:
#             try:
#                 details = line.split("&&")
#                 name = f"{details[0]}-{details[2]}-{details[3]}"
            
#                 plan = details[-1]
#                 trace = read_plan(plan)
           

#                 domain_name = details[0]
            
#                 exe_l, exe_gt = test_cross_exe(domain_name, trace, trace)
#             except Exception as e:
#                 print(f"Error processing task {name}: {e}")
#                 exe_l, exe_gt = 0, 0
#             print(f"Executability for {name}: {exe_l}, {exe_gt}")
#             out.write(f"{name},{exe_l}, {exe_gt}\n")
#             out.flush()
